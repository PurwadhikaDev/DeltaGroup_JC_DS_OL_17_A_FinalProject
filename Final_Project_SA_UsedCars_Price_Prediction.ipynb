# %% [markdown]
# # Saudi Used Cars Price Prediction

# %% [markdown]
# ## Created By : Muhammad Daffa Hilmy & Evelio Excellenta

# %% [markdown]
# ## Business Problem Understanding
#
# ### 1. Business Problem
#
# Di pasar otomotif Arab Saudi yang dinamis, menentukan harga wajar mobil bekas dapat menjadi tantangan bagi pembeli dan penjual. Pembeli ingin menghindari membayar terlalu mahal, sementara penjual perlu menentukan harga kendaraan mereka secara akurat agar tetap kompetitif dan memaksimalkan keuntungan mereka. Pasar daring dan dealer mobil sama-sama membutuhkan metode yang efisien dan berbasis data untuk memastikan harga yang wajar, meningkatkan kepercayaan pelanggan, dan meminimalkan waktu yang dihabiskan untuk negosiasi.
#
# ---
#
# ### 2. Stakeholders and Their Needs
#
# 1. **Penjual Perorangan (Pemilik Pribadi)**
#     - **Kebutuhan**: Kisaran harga yang dapat diandalkan untuk menjual mobil mereka, mengurangi perkiraan dan potensi kerugian akibat harga yang terlalu rendah.
#     - **Nilai**: Penjualan lebih cepat, waktu negosiasi lebih sedikit, dan penilaian wajar yang mencerminkan kondisi pasar terkini.
#
# 2. **Dealer Mobil**
#     - **Kebutuhan**: Penetapan harga yang cepat dan konsisten untuk mengelola inventaris besar dan mengoptimalkan margin laba.
#     - **Nilai**: Mempertahankan daftar yang kompetitif, meningkatkan kepuasan pelanggan dengan memberikan harga yang transparan, dan meminimalkan waktu penjualan.
#
# 3. **Pasar Daring (misalnya, Syarah.com)**
#     - **Kebutuhan**: Sistem untuk merekomendasikan kisaran harga yang akurat untuk daftar pengguna dan memverifikasi kewajaran harga yang dipasang penjual.
#     - **Nilai**: Reputasi yang ditingkatkan untuk memberikan rekomendasi yang transparan dan didukung data, yang mengarah pada kepercayaan pengguna yang lebih tinggi dan keandalan platform.
#
# 4. **Lembaga Keuangan (Bank, Perusahaan Asuransi)**
#     - **Kebutuhan**: Model penilaian kendaraan yang akurat untuk penjaminan pinjaman, penentuan premi asuransi, dan evaluasi risiko.
#     - **Nilai**: Risiko gagal bayar yang lebih rendah, perhitungan premi yang wajar, dan peningkatan kepuasan pelanggan dengan cakupan dan suku bunga pinjaman yang wajar.
#
# 5. **Pembeli**
#     - **Kebutuhan**: Keyakinan akan kewajaran harga yang diminta untuk kendaraan.
#     - **Nilai**: Keputusan pembelian yang lebih sederhana dan cepat, serta risiko membayar lebih untuk kendaraan yang tidak sesuai dengan nilai pasarnya yang berkurang.
#
# ### 3. Problem Statement
# Pasar mobil bekas di Arab Saudi seringkali menyulitkan baik pembeli maupun penjual dalam menentukan harga yang wajar dan akurat untuk kendaraan yang telah digunakan. Berbagai faktor—seperti usia kendaraan, jarak tempuh, reputasi merek, dan perbedaan kondisi regional—membuat proses penilaian harga menjadi kompleks. Mobil yang dipasang dengan harga terlalu tinggi cenderung tidak laku karena kurang diminati pembeli, sementara mobil yang dipasarkan dengan harga terlalu rendah dapat merugikan penjual akibat kehilangan potensi pendapatan. Kurangnya transparansi penetapan harga turut mengurangi kepercayaan pembeli serta memperlambat proses transaksi, sehingga menciptakan ketidakefisienan bagi semua pihak yang terlibat.
#
# ### 4. Project Goals
# Untuk mengatasi tantangan ini, tujuan utama kami adalah mengembangkan model prediktif berbasis data yang dapat memperkirakan nilai mobil bekas dengan akurat. Dengan memanfaatkan berbagai atribut kendaraan—seperti merek, tahun pembuatan, jarak tempuh, dan spesifikasi mesin—ke dalam kerangka analisis yang komprehensif, kami bertujuan untuk memberikan rekomendasi harga yang adil dan konsisten. Model ini akan membantu penjual menetapkan harga yang kompetitif, serta memudahkan pembeli menilai nilai pasar kendaraan secara cepat, sehingga waktu negosiasi berkurang dan ketidakpastian dapat diminimalisasi. Selain itu, solusi ini akan bermanfaat bagi dealer mobil, platform jual-beli daring, dan lembaga keuangan yang mengandalkan penentuan harga andal guna menyederhanakan operasi, meningkatkan kepercayaan konsumen, dan mengoptimalkan efisiensi pasar secara keseluruhan.

# %% [markdown]
# ### 5. Analytical Approach
# - **Sifat Variabel Target:**
#   Harga mobil bekas merupakan nilai kontinu (angka), bukan kategori diskrit. Model regresi dirancang untuk memprediksi nilai numerik, sedangkan klasifikasi lebih cocok untuk memprediksi label/kategori.
#
# - **Tujuan Prediksi Nilai Eksak:**
#   Ketika kita ingin mengetahui perkiraan harga (misalnya Rp100 juta vs. Rp150 juta), model regresi memberikan output numerik yang lebih tepat. Dalam klasifikasi, kita hanya akan mendapatkan label kelas (misalnya “Murah”, “Sedang”, “Mahal”) tanpa nilai detail.
#
# - **Analisis Kuantitatif:**
#   Pendekatan regresi memungkinkan kita untuk menghitung error metrik (misalnya RMSE, MAE) yang dapat menunjukkan seberapa jauh prediksi dari nilai aktual. Hal ini penting untuk mengevaluasi akurasi prediksi harga.
#
# - **Fleksibilitas dan Interpretasi Bisnis:**
#   Dengan regresi, kita dapat menganalisis perbedaan harga dalam satuan mata uang yang jelas. Ini memudahkan interpretasi dalam konteks bisnis, misalnya untuk menentukan strategi penetapan harga atau estimasi biaya.
#
# Secara keseluruhan, **regresi** dipilih karena kita membutuhkan **prediksi nilai kontinu** (harga) yang dapat diukur tingkat kesalahannya, bukan sekadar pengelompokan ke dalam kategori tertentu.

# %% [markdown]
# ## Data Understanding

# %% [markdown]
# Data Source : https://www.kaggle.com/datasets/turkibintalib/saudi-arabia-used-cars-dataset
#
# Note :
# - Dataset berisi 8035 record mobil bekas yang dikumpulkan dari syarah.com
# - Data yang terupdate ada hingga tahun 2022
# - Setiap baris mewakili satu unit mobil bekas yang dijual dan setiap kolom merepresentasikan atribut atau karakteristik mobil
# - Terdapat 13 kolom, Berdasarkan tipenya ada 4 kolom Numerik dan 9 kolom kategorikal, secara detail terdapat 8 tipe data object, 3 tipe data integer, 1 tipe data float dan 1 tipe data boolean.

# %% [markdown]
# ### Attribute Information
#
# | Attribute     | Data Type | Description                                               |
# |---------------|------------|-----------------------------------------------------------|
# | Type          | Object     | Jenis mobil bekas                                         |
# | Region        | Object     | Wilayah tempat mobil bekas ditawarkan                    |
# | Make          | Object     | Nama perusahaan / merek mobil                            |
# | Gear_Type     | Object     | Jenis transmisi mobil (manual/otomatis)                  |
# | Origin        | Object     | Asal mobil (misalnya lokal atau impor)                   |
# | Options       | Object     | Opsi atau fitur tambahan yang dimiliki mobil             |
# | Year          | Int64      | Tahun pembuatan mobil                                    |
# | Engine_Size   | Float64    | Ukuran mesin mobil                           |
# | Mileage       | Int64      | Jarak tempuh mobil dalam kilometer                       |
# | Negotiable    | Bool       | Apakah harga bisa dinego (True = bisa dinego)           |
# | Price         | Int64      | Harga mobil dalam satuan mata uang lokal (SAR)           |
# | Fuel_Type     | Object     | Jenis bahan bakar mobil (Gas, Diesel, Hybrid)        |
# | Color     | Object     | Warna mobil        |

# %% [markdown]
# ## 1. Import Libraries

# %%
# Import library yang dibutuhkan
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# statistical
from scipy.stats import shapiro

# machine learning
import category_encoders as ce
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import RandomizedSearchCV
from xgboost import plot_importance

# warnings
import warnings
warnings.simplefilter("ignore")

# visualisasi
from plotly.subplots import make_subplots
import plotly.express as px

# Agar grafik langsung muncul dalam notebook
# %matplotlib inline

# %% [markdown]
# ## 2. Load Dataset

# %%
df = pd.read_csv('UsedCarsSA_Clean_EN.csv')
df.head()
# Out:
#        Make     Type  Year Origin   Color    Options  Engine_Size Fuel_Type  \
# 0  Chrysler     C300  2018  Saudi   Black       Full          5.7       Gas
# 1    Nissan   Patrol  2016  Saudi   White       Full          4.8       Gas
# 2    Nissan    Sunny  2019  Saudi  Silver   Standard          1.5       Gas
# 3   Hyundai  Elantra  2019  Saudi    Grey   Standard          1.6       Gas
# 4   Hyundai  Elantra  2019  Saudi  Silver  Semi Full          2.0       Gas
#
#    Gear_Type  Mileage  Region   Price  Negotiable
# 0  Automatic   103000  Riyadh  114000       False
# 1  Automatic     5448  Riyadh       0        True
# 2  Automatic    72418  Riyadh   27500       False
# 3  Automatic   114154  Riyadh   43000       False
# 4  Automatic    41912  Riyadh   59500       False

# %%
# Count and Datatype for each Column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8035 entries, 0 to 8034
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         8035 non-null   object
#  1   Type         8035 non-null   object
#  2   Year         8035 non-null   int64
#  3   Origin       8035 non-null   object
#  4   Color        8035 non-null   object
#  5   Options      8035 non-null   object
#  6   Engine_Size  8035 non-null   float64
#  7   Fuel_Type    8035 non-null   object
#  8   Gear_Type    8035 non-null   object
#  9   Mileage      8035 non-null   int64
#  10  Region       8035 non-null   object
#  11  Price        8035 non-null   int64
#  12  Negotiable   8035 non-null   bool
# dtypes: bool(1), float64(1), int64(3), object(8)
# memory usage: 761.3+ KB

# %%
# Menampilkan ringkasan statistik
df.describe()
# Out:
#               Year  Engine_Size       Mileage         Price
# count  8035.000000  8035.000000  8.035000e+03  8.035000e+03
# mean   2014.097698     3.287729  1.491488e+05  5.369984e+04
# std       5.757228     1.517747  3.474480e+05  7.198472e+04
# min    1963.000000     1.000000  1.000000e+02  0.000000e+00
# 25%    2012.000000     2.000000  3.700000e+04  0.000000e+00
# 50%    2016.000000     3.000000  1.019600e+05  3.700000e+04
# 75%    2018.000000     4.400000  1.950000e+05  7.375000e+04
# max    2022.000000     9.000000  2.000000e+07  1.150000e+06

# %% [markdown]
# ## 3. Exploratory Data Analysis (EDA) & Data Cleaning

# %% [markdown]
# #### 3.1 Overview Dataset

# %%
# Mengecek setiap kolom untuk data yang unik dan memastikan tipe data sudah benar, yaitu antara bentuknya string atau numerik
# Buat list kosong untuk menyimpan informasi tiap kolom
summary = []

# Loop untuk setiap kolom
for col in df.columns:
    unique_vals = df[col].unique()
    dtype = df[col].dtype
    num_unique = len(unique_vals)
    
    # Ambil contoh nilai unik (maksimal 5)
    sample_vals = unique_vals[:5]
    sample_vals_str = ', '.join(map(str, sample_vals))
    if num_unique > 5:
        sample_vals_str += ', ...'
    
    # Tambahkan ke dalam list summary
    summary.append({
        'Column Name': col,
        'Data Type': dtype,
        'Unique Values': num_unique,
        'Sample Values': sample_vals_str
    })

# Buat DataFrame ringkasan
summary_df = pd.DataFrame(summary)
# Tampilkan tabel ringkasan
summary_df
# Out:
#     Column Name Data Type  Unique Values  \
# 0          Make    object             59
# 1          Type    object            381
# 2          Year     int64             52
# 3        Origin    object              4
# 4         Color    object             15
# 5       Options    object              3
# 6   Engine_Size   float64             75
# 7     Fuel_Type    object              3
# 8     Gear_Type    object              2
# 9       Mileage     int64           2175
# 10       Region    object             27
# 11        Price     int64            541
# 12   Negotiable      bool              2
#
#                                      Sample Values
# 0    Chrysler, Nissan, Hyundai, Honda, Toyota, ...
# 1        C300, Patrol, Sunny, Elantra, Accord, ...
# 2                2018, 2016, 2019, 2011, 2009, ...
# 3               Saudi, Gulf Arabic, Other, Unknown
# 4            Black, White, Silver, Grey, Navy, ...
# 5                        Full, Standard, Semi Full
# ...

# %% [markdown]
# ##### Ringkasan Struktur Dataset
#
# Dataset terdiri dari 8.035 baris dan 13 kolom. Setiap kolom mewakili atribut penting dari mobil bekas yang dijual, seperti merek (`Make`), tipe (`Type`), tahun pembuatan (`Year`), ukuran mesin (`Engine_Size`), dan harga (`Price`).
#
# Sebagian besar fitur bertipe kategorikal (object), sementara kolom `Year`, `Mileage`, dan `Engine_Size` bersifat numerik. Kolom `Negotiable` bertipe boolean dan akan dievaluasi karena hanya memiliki satu nilai.
#
# Berikut adalah jumlah nilai unik untuk fitur kategorikal:
#
# - `Make`: 59 kategori
# - `Type`: 381 kategori → perlu ditangani karena sangat tinggi (high cardinality)
# - `Color`, `Region`, `Fuel_Type`, dan lainnya menunjukkan variasi yang masih wajar dan dapat digunakan langsung dalam visualisasi.

# %%
# Melihat jumlah missing values per kolom
df.isnull().sum()
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# Dapat dilihat bahwa dataset tidak memiliki null values

# %% [markdown]
# #### 3.2 Cek Data Duplikat

# %%
# Mengecek jumlah data duplikat
print("Jumlah duplikat:", df.duplicated().sum())
# Out:
# Jumlah duplikat: 3

# %% [markdown]
# Dataset memiliki 3 data duplikat yang perlu dihapus.

# %%
# Menghapus data duplikat (jika memang tidak dibutuhkan)
df.drop_duplicates(inplace=True)

# Verifikasi apakah duplikat sudah terhapus
print("Jumlah duplikat setelah dihapus:", df.duplicated().sum())
# Out:
# Jumlah duplikat setelah dihapus: 0

# %% [markdown]
# #### 3.3 Statistik deskriptif untuk fitur numerik

# %% [markdown]
# Analisis statistik deskriptif dilakukan terhadap fitur numerik dalam dataset, yaitu: Year, Engine_Size, Mileage, dan Price. Statistik ini memberikan gambaran umum mengenai sebaran nilai, kecenderungan pusat, dan penyebaran data.

# %%
# Ambil kolom numerik
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns

# Statistik deskriptif untuk kolom numerik
numeric_summary = df[numeric_cols].describe().T
numeric_summary
# Out:
#               count           mean            std     min      25%       50%  \
# Year         8032.0    2014.097112       5.758021  1963.0   2012.0    2016.0
# Engine_Size  8032.0       3.287774       1.518001     1.0      2.0       3.0
# Mileage      8032.0  149152.841011  347512.247719   100.0  37000.0  101785.5
# Price        8032.0   53699.225722   71993.850987     0.0      0.0   37000.0
#
#                   75%         max
# Year           2018.0      2022.0
# Engine_Size       4.4         9.0
# Mileage      195000.0  20000000.0
# Price         73625.0   1150000.0

# %% [markdown]
# ####  Year (Tahun Pembuatan)
# - Rata-rata tahun pembuatan mobil bekas adalah **2014**, dengan rentang antara **1963 hingga 2018**.
# - Mayoritas kendaraan berada di rentang **2012–2016**, menunjukkan bahwa sebagian besar mobil yang dijual berusia **5–10 tahun**.
#
# ####  Engine Size (Ukuran Mesin)
# - Rata-rata ukuran mesin adalah **3.28 liter**, dengan sebaran dari **1.0 hingga 4.4 liter**.
# - Median sebesar **3.0 liter**, mengindikasikan bahwa kebanyakan mobil memiliki kapasitas mesin sedang hingga besar, sesuai karakteristik mobil di wilayah Arab Saudi.
#
# ####  Mileage (Jarak Tempuh)
# - Rata-rata jarak tempuh mencapai **149.512 km**, dengan standar deviasi cukup besar (±34.752 km).
# - 50% mobil memiliki jarak tempuh di bawah **101.786 km**, menunjukkan penggunaan yang masih relatif wajar untuk pasar mobil bekas.
#
# ####  Price (Harga)
# - Rata-rata harga mobil adalah **53.699 SAR**, dengan nilai maksimum mencapai **736.250 SAR**.
# - Terdapat **2.526 data** dengan harga **0 SAR**, yang dianggap tidak valid dan akan dihapus.
# - Penyebaran harga sangat tinggi, mencerminkan keberagaman segmen kendaraan dari murah hingga mewah.
#
# #### Insight & Tindakan
# - Harga dan jarak tempuh memiliki penyebaran data yang sangat luas, sehingga perlu penanganan outlier lebih lanjut.
# - Nilai 0 pada kolom `Price` akan dihapus karena tidak valid secara bisnis dan dapat memengaruhi distribusi model.

# %% [markdown]
# ####  Distribusi Awal Harga (Price)

# %%
df[df['Price'] == 0].shape[0]
# Out:
# 2526

# %% [markdown]
# Distribusi awal harga mobil menunjukkan bahwa terdapat **2.526 data** dengan nilai `Price = 0`. Nilai ini tidak valid secara bisnis, karena tidak mungkin ada mobil yang dijual dengan harga 0.

# %% [markdown]
# ##### Visualisasi Kolom Price sebelum di bersihkan

# %%
import plotly.express as px

fig = px.histogram(df, x='Price', nbins=50, title='Distribution of Price')
fig.update_layout(xaxis_title='Price', yaxis_title='Frequency')
fig.show()

# %% [markdown]
# Dapat dilihat histogram menunjukkan konsentrasi ekstrem di ujung kiri (harga sangat rendah), yang menyebabkan distribusi menjadi sangat miring ke kanan (**right-skewed**).

# %%
len(df)
# Out:
# 8032

# %% [markdown]
# Menghapus tipe mobil yang jumlahnya kurang dari 50, tujuannya agar mengurangi kardinalitas tinggi dan memperbaiki kemampuan model dalam memprediksi harga.

# %%
# Determine the 'Type' values that occur 50 times or less in the DataFrame 'df' 
# and store these values' indices in 'drop_type'

drop_type = df.Type.value_counts()[df.Type.value_counts() <= 50].index
drop_type
# Out:
# Index(['C300', 'Malibu', 'Cadenza', 'Hiace', 'Rav4', 'LS', 'Land Cruiser 70',
#        'Edge', 'Other', 'Sportage',
#        ...
#        'Camargue', 'Coupe S', 'Golf', 'Arnage', 'Patriot', 'LF X60', 'Crown',
#        'Koranado', 'Prius', 'Galant'],
#       dtype='object', name='Type', length=334)

# %%
# For each value 'i' in 'drop_type':
for i in drop_type:
    # Find the indices where the 'Type' column in the DataFrame 'df' matches the value 'i'
    drop_index = df[df['Type'] == i].index

    # Drop rows from 'df' based on the found indices
    df.drop(index=drop_index, inplace=True)

# Reset the indices of 'df' after dropping rows and make the changes permanent
df.reset_index(drop=True, inplace=True)

df.Type.value_counts()
# Out:
# Type
# Land Cruiser           372
# Camry                  328
# Hilux                  290
# Accent                 250
# Yukon                  230
# Tahoe                  218
# Sonata                 213
# Taurus                 203
# Elantra                189
# Corolla                171
# Expedition             151
# Furniture              129
# Suburban               125
# Accord                 119
# ES                     117
# LX                     110
# S                      108
# Patrol                 108
# Prado                  105
# Sunny                  105
# Yaris                   96
# Range Rover             93
# Land Cruiser Pickup     93
# Pajero                  90
# Sierra                  88
# Caprice                 87
# FJ                      83
# Innova                  81
# Datsun                  80
# Charger                 77
# Explorer                71
# C                       69
# Senta fe                69
# 6                       66
# ...

# %% [markdown]
# Selanjutnya, dilakukan pembersihan data untuk menghapus semua nilai `Price ≤ 1` agar distribusi menjadi lebih representatif dan siap dianalisis lebih lanjut.

# %%
df = df[df['Price'] > 1].copy()

# %%
len(df)
# Out:
# 3760

# %% [markdown]
# ##### Visualisasi Kolom Price sesudah di bersihkan

# %%
import plotly.express as px

fig = px.histogram(df, x='Price', nbins=50, title='Distribution of Price')
fig.update_layout(xaxis_title='Price', yaxis_title='Frequency')
fig.show()

# %%
# Ambil kolom numerik
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns

# Statistik deskriptif untuk kolom numerik
numeric_summary = df[numeric_cols].describe().T
numeric_summary
# Out:
#               count           mean            std     min      25%       50%  \
# Year         3760.0    2014.943085       4.849252  1964.0   2014.0    2016.0
# Engine_Size  3760.0       3.236436       1.488243     1.0      2.0       2.7
# Mileage      3760.0  141466.670745  200768.424362   100.0  53000.0  105261.0
# Price        3760.0   79693.732181   72342.334465   850.0  36000.0   58000.0
#
#                   75%        max
# Year           2018.0     2021.0
# Engine_Size       4.3        9.0
# Mileage      190000.0  4500000.0
# Price         96000.0   748000.0

# %% [markdown]
# Terlihat data sudah menunjukkan price terkecil berada di 850 SAR dan tidak di 0 lagi

# %% [markdown]
# #### 3.4 Distribusi Fitur Numerik

# %% [markdown]
# Selanjutnya kita akan melakukan tes distribusi,
# Mengapa Perlu Melakukan Tes Distribusi Normal dan Menggunakan Shapiro-Wilk Test?
#
# - **Memahami Karakteristik Data:**
#   Tes distribusi normal membantu kita memahami apakah data mengikuti pola distribusi normal (Gaussian). Ini penting karena banyak analisis statistik dan model prediktif mengasumsikan data atau residual yang berdistribusi normal.
#
# - **Validasi Asumsi Statistik:**
#   Beberapa metode statistik (misalnya, uji parametrik atau analisis regresi) mengandalkan asumsi normalitas. Jika data tidak normal, hasil uji statistik mungkin tidak valid atau interpretasinya bisa menyesatkan.
#
# - **Pemilihan Teknik Pemodelan:**
#   Mengetahui distribusi data memungkinkan kita menentukan apakah perlu dilakukan transformasi data (seperti log-transformasi) untuk mencapai normalitas atau memilih model yang tidak terlalu sensitif terhadap distribusi data.
#
# - **Mengapa Shapiro-Wilk Test?**
#   - **Sensitivitas:** Shapiro-Wilk adalah salah satu tes yang paling sensitif untuk mendeteksi penyimpangan dari distribusi normal, terutama pada sampel berukuran kecil hingga sedang.
#   - **Kemudahan Implementasi:** Tes ini mudah diimplementasikan dengan library seperti SciPy dan memberikan p-value yang membantu dalam pengambilan keputusan (misalnya, p-value < 0.05 menunjukkan data kemungkinan tidak berdistribusi normal).
#
# Dengan melakukan tes distribusi normal, kita dapat memastikan bahwa asumsi-asumsi penting terpenuhi atau mengetahui kapan harus melakukan penyesuaian agar analisis atau model yang dibangun lebih akurat dan valid.

# %%
import plotly.express as px
from scipy.stats import shapiro
import warnings
warnings.simplefilter("ignore")

numeric_cols = ['Price', 'Mileage', 'Year', 'Engine_Size']

for col in numeric_cols:
    print("="*60)
    print(f"Analisis Kolom: {col}")
    
    # 1. Histogram + KDE menggunakan Plotly
    fig = px.histogram(df, x=col, nbins=50, marginal="box", title=f'Distribusi Kolom {col}', opacity=0.7)
    fig.update_layout(bargap=0.2)
    fig.show()
    
    # 2. Shapiro-Wilk Test
    # Pastikan kolom tidak mengandung NaN sebelum dijalankan
    data_non_null = df[col].dropna()
    stat, p_val = shapiro(data_non_null)
    
    print(f"Shapiro-Wilk Test untuk kolom {col}:")
    print(f"  Statistik = {stat:.4f}, p-value = {p_val:.4f}")
    if p_val < 0.05:
        print("  => Data kemungkinan TIDAK terdistribusi normal (Reject H0).")
    else:
        print("  => Data berpotensi terdistribusi normal (Fail to reject H0).")
    print("="*60)
    print("\n")
# Out:
# ...
# Analisis Kolom: Price
# Shapiro-Wilk Test untuk kolom Price:
#   Statistik = 0.7365, p-value = 0.0000
#   => Data kemungkinan TIDAK terdistribusi normal (Reject H0).
# ...
#
#
# ...
# Analisis Kolom: Mileage
# Shapiro-Wilk Test untuk kolom Mileage:
#   Statistik = 0.4348, p-value = 0.0000
#   => Data kemungkinan TIDAK terdistribusi normal (Reject H0).
# ...
#
#
# ...
# Analisis Kolom: Year
# Shapiro-Wilk Test untuk kolom Year:
#   Statistik = 0.7977, p-value = 0.0000
#   => Data kemungkinan TIDAK terdistribusi normal (Reject H0).
# ...
#
#
# ...
# Analisis Kolom: Engine_Size
# Shapiro-Wilk Test untuk kolom Engine_Size:
#   Statistik = 0.9294, p-value = 0.0000
#   => Data kemungkinan TIDAK terdistribusi normal (Reject H0).
# ...

# %% [markdown]
# **Important Note** : Karena datanya tidak terdistribusi normal maka kita akan menggunakan metode IQR untuk mendeteksi outliers.
#
# ### Menggunakan Metode IQR untuk Deteksi Outliers
#
# - **Tidak Bergantung pada Asumsi Normalitas:**
#   IQR merupakan metode non-parametrik yang tidak mengasumsikan data berdistribusi normal, sehingga cocok untuk dataset yang tidak terdistribusi normal.
#
# - **Robust terhadap Outliers:**
#   Dengan memfokuskan analisis pada rentang kuartil (Q1 sampai Q3), IQR mengabaikan nilai ekstrem sehingga lebih tahan terhadap pengaruh outlier dibandingkan dengan metode berbasis mean dan standar deviasi.
#
# - **Simplicity dan Efektivitas:**
#   IQR mudah dihitung dan diinterpretasikan dengan menggunakan aturan 1.5 * IQR untuk menentukan batas bawah dan atas, membuatnya menjadi pendekatan yang efektif untuk mendeteksi nilai-nilai yang menyimpang secara signifikan.
#
# - **Fokus pada Data Tengah:**
#   Metode ini menangkap informasi dari 50% data tengah (antara Q1 dan Q3), yang memberikan gambaran yang lebih stabil tentang sebaran data dan membantu mengidentifikasi outliers dengan lebih tepat.

# %%
numeric_columns = ['Year', 'Engine_Size', 'Mileage', 'Price']

for col in numeric_columns:
    # 1. Menghitung Q1, Q3, dan IQR
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    # 2. Menentukan batas bawah dan batas atas
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # 3. Filter baris-baris yang termasuk outlier
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]

    # 4. Menampilkan jumlah outlier dan persentase relatif terhadap total baris
    total_rows = len(df)
    num_outliers = len(outliers)
    percentage_outliers = (num_outliers / total_rows) * 100

    print(f"Kolom: {col}")
    print(f"Jumlah Outlier: {num_outliers} dari {total_rows} baris data ({percentage_outliers:.2f}%).")
    print(f"Batas Bawah = {lower_bound}, Batas Atas = {upper_bound}")
    
    if num_outliers > 0:
        # Menampilkan semua nilai outlier yang unik untuk kolom tersebut
        unique_outliers = sorted(outliers[col].unique())
        print(f"Nilai Outlier Unik untuk '{col}': {unique_outliers}")
    
    print("-"*50)
    
    # 5. Visualisasi dengan Boxplot
    plt.figure(figsize=(6, 4))
    sns.boxplot(x=df[col])
    
    # Tambahkan garis bantu untuk lower_bound dan upper_bound (opsional)
    plt.axvline(x=lower_bound, color='red', linestyle='--', label='Lower Bound')
    plt.axvline(x=upper_bound, color='blue', linestyle='--', label='Upper Bound')
    
    plt.title(f'Boxplot untuk Kolom {col}')
    plt.legend()
    plt.show()
# Out:
# Kolom: Year
# Jumlah Outlier: 279 dari 3760 baris data (7.42%).
# Batas Bawah = 2008.0, Batas Atas = 2024.0
# Nilai Outlier Unik untuk 'Year': [1964, 1978, 1980, 1983, 1984, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007]
# --------------------------------------------------
# Kolom: Engine_Size
# Jumlah Outlier: 29 dari 3760 baris data (0.77%).
# Batas Bawah = -1.4499999999999997, Batas Atas = 7.75
# Nilai Outlier Unik untuk 'Engine_Size': [7.9, 8.0, 8.1, 8.7, 8.9, 9.0]
# --------------------------------------------------
# Kolom: Mileage
# Jumlah Outlier: 129 dari 3760 baris data (3.43%).
# Batas Bawah = -152500.0, Batas Atas = 395500.0
# ...

# %% [markdown]
# **Important Point** : Berdasarkan apa yang sudah kita deteksi mengenai outliers, maka kita akan mengambil langkah dengan menghapus outliers dengan nilai yang ekstrem saja. Berikut yang akan kita lakukan :
# - Berdasarkan distribusi dan konteks bisnis, pembersihan dilakukan terhadap:
#   - `Year` di bawah 1970 (asumsi teknologi atau relevansi pasar)
#   - `Mileage` di atas 432.000 km
#   - `Price` di bawah 5.000 SAR dan di atas 440.000 SAR
# - Kolom `Engine_Size` memiliki variasi yang **masih dapat diterima secara bisnis** (mobil sport, SUV besar, dsb), sehingga tidak dihapus.
#
# tambahan konteks : penentuan batas bawah price ini didasari dengan pencarian di online marketplace di arab (https://ksa.yallamotor.com/used-cars/under-5000-sar?sort=price_desc ) yang menunjukkan bahwa harga mobil terendah berada di 5000 SAR. price yang tinggi sebenarnya bisa dibenarkan karena yang memiliki price tinggi adalah mobil-mobil premium/mewah sehingga wajar harganya tinggi. namun sebenarnya memang tergantung tujuan bisnis, jika secara umum segmen pasarnya adalah menengah ke bawah maka sebaiknya mobil premium agak dihapuskan saja, namun disini kita asumsikan pasarnya mencakup keseluruhan level kelas ekonomi, jadi untuk beberapa mobil premium akan tetap ada, itulah sebabnya batasnya 1000000.

# %%
# Simpan jumlah baris sebelum pembersihan
initial_count = len(df)

# 1. Hapus baris dengan kolom 'Year' < 1970
df = df[df['Year'] > 1970]

# 2. Engine_Size dipertahankan (tidak dihapus outliernya),
#    sehingga tidak ada filter untuk 'Engine_Size'.

# 3. Hapus baris dengan kolom 'Mileage' > 7.500.000
df = df[df['Mileage'] <= 432000]

# 4. Hapus baris dengan kolom 'Price' > 1.000.000 dan dibawah 5000
df = df[(df['Price'] <= 440000) & (df['Price'] >= 5000)]

# Simpan jumlah baris setelah pembersihan
final_count = len(df)
removed_rows = initial_count - final_count

print(f"Jumlah baris awal: {initial_count}")
print(f"Jumlah baris setelah menghapus outliers: {final_count}")
print(f"Total baris yang dihapus: {removed_rows}")
# Out:
# Jumlah baris awal: 3760
# Jumlah baris setelah menghapus outliers: 3589
# Total baris yang dihapus: 171

# %% [markdown]
# Setelah dilakukan penghapusan outlier, kita mendapatkan total baris yang dihapus berjumlah 171. Sehingga data kita berubah dari 3760 baris menjadi 3589 baris

# %% [markdown]
# #### 3.5 Analisis Kolerasi Numerik

# %% [markdown]
# Melakukan pengecekan korelasi dengan metode spearman karena data kita tidak terdistribusi normal
#
# - **Mengapa Menggunakan Metode Spearman:**
#   - Spearman adalah metode non-parametrik yang mengukur korelasi berdasarkan peringkat (ranks), sehingga tidak terpengaruh oleh asumsi normalitas data.
#   - Metode ini mampu mendeteksi hubungan monotonic antara variabel, meskipun hubungan tersebut tidak linier, sehingga lebih cocok untuk dataset yang tidak terdistribusi normal.
#
# - **Mengapa Melihat Korelasi Antar Fitur Numerikal:**
#   - Analisis korelasi membantu mengidentifikasi hubungan antara fitur, sehingga kita bisa memahami apakah terdapat fitur yang sangat berkorelasi dan berpotensi redundan.
#   - Mengetahui korelasi antar fitur juga berguna untuk mendeteksi multikolinearitas, yang dapat mempengaruhi stabilitas dan interpretabilitas model prediktif.

# %%
# Daftar kolom yang ingin dilihat korelasinya
cols = ['Year', 'Engine_Size', 'Mileage', 'Price']

# 1) Membuat subset DataFrame hanya dengan 4 kolom numerik tersebut
df_corr = df[cols].copy()

# 2) Menghitung korelasi dengan metode Spearman (karena data non-normal)
corr_matrix = df_corr.corr(method='spearman')

# 3) Menampilkan nilai korelasi dalam bentuk tabel
print("Matriks Korelasi (Spearman):")
print(corr_matrix)

# 4) Visualisasi dengan Heatmap Seaborn
plt.figure(figsize=(6, 5))
sns.heatmap(corr_matrix, 
            annot=True,        # menampilkan nilai korelasi di tiap sel
            cmap='coolwarm',   # skema warna
            vmin=-1, vmax=1,   # mengatur rentang warna dari -1 s/d 1
            square=True)       # sel heatmap berbentuk kotak

plt.title('Spearman Correlation Heatmap')
# Out:
# Matriks Korelasi (Spearman):
#                  Year  Engine_Size   Mileage     Price
# Year         1.000000    -0.301532 -0.455619  0.406004
# Engine_Size -0.301532     1.000000  0.123516  0.442288
# Mileage     -0.455619     0.123516  1.000000 -0.264097
# Price        0.406004     0.442288 -0.264097  1.000000
# Text(0.5, 1.0, 'Spearman Correlation Heatmap')

# %% [markdown]
# ####  Interpretasi Hasil Heatmap Korelasi:
# - Terdapat korelasi **positif sedang** antara `Year` dan `Price` sebesar **0.40**, menunjukkan bahwa mobil yang lebih baru cenderung memiliki harga jual lebih tinggi.
# - `Engine_Size` juga memiliki korelasi **positif** dengan `Price` sebesar **0.44**, artinya semakin besar ukuran mesin, cenderung semakin mahal mobil tersebut.
# - Sebaliknya, `Mileage` berkorelasi **negatif** dengan `Price` sebesar **-0.26**, yang menunjukkan bahwa semakin jauh mobil telah digunakan, semakin rendah harga jualnya.
# - Tidak ada korelasi ekstrem antar fitur numerikal lainnya yang mengindikasikan multikolinearitas kuat, sehingga **semua fitur masih layak dipertimbangkan dalam pemodelan**.
#
# Insight:
# Meskipun hubungan antar fitur tidak semuanya kuat, hubungan yang ditemukan cukup masuk akal secara domain. Kombinasi `Year`, `Engine_Size`, dan `Mileage` dapat digunakan sebagai prediktor penting untuk menentukan `Price` pada tahap modeling nanti.

# %% [markdown]
# #### 3.6 Distribusi Fitur Kategorikal

# %%
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# Daftar fitur kategorikal
categorical_features = ['Make', 'Region', 'Gear_Type', 'Fuel_Type', 'Origin', 'Options', 'Color', 'Type']

# Buat subplot 4 baris x 2 kolom
fig = make_subplots(rows=4, cols=2, subplot_titles=[f'Distribusi Kategori: {feat}' for feat in categorical_features])

# Loop setiap fitur
for i, feature in enumerate(categorical_features):
    row = i // 2 + 1
    col = i % 2 + 1

    # Ambil 15 kategori teratas
    top_categories = df[feature].value_counts().nlargest(15).index
    filtered_df = df[df[feature].isin(top_categories)]

    # Hitung frekuensi kategori
    counts = filtered_df[feature].value_counts().loc[top_categories]

    # Buat bar plot (count plot)
    trace = go.Bar(x=counts.index, y=counts.values, name=feature)
    fig.add_trace(trace, row=row, col=col)

    # Rotate label sumbu x
    fig.update_xaxes(tickangle=45, row=row, col=col)
    fig.update_yaxes(title_text='Count', row=row, col=col)

# Update layout keseluruhan
fig.update_layout(height=1000, width=1500, title_text='Distribusi Kategori Fitur (Top 15)', showlegend=False)
fig.show()

# %% [markdown]
# - Mayoritas mobil bekas yang tersedia di pasar Arab Saudi berasal dari merek Toyota, dengan total lebih dari 1.000 unit tercatat di dataset, jauh melebihi Hyundai (sekitar 600 unit) dan Ford (sekitar 400 unit). Preferensi ini menunjukkan dominasi Toyota sebagai brand terpercaya di pasar, yang bisa diasumsikan karena daya tahan dan nilai jual kembali yang baik. Oleh karena itu, platform penjualan mobil bekas sebaiknya mengarahkan kampanye promosi kepada dealer Toyota dan mengutamakan merek ini dalam strategi penempatan produk, karena hal ini dapat meningkatkan keterlibatan pengguna dan konversi hingga 20–30% dibanding merek lain dengan jumlah listing lebih kecil.
#
# - Fitur `Region` awalnya menunjukkan bahwa lebih dari 2.000 mobil berasal dari Riyadh, diikuti oleh Dammam (sekitar 1.000 unit), namun fitur ini sangat berkorelasi dengan fitur `Origin` yang sudah menjelaskan asal geografis mobil. Oleh karena itu, untuk menghindari redudansi dan multikolinearitas, `Region` diputuskan untuk dihapus dari dataset.
#
# - Dari sisi transmisi, sebanyak 90% kendaraan menggunakan transmisi otomatis, dengan hanya sekitar 500 kendaraan menggunakan transmisi manual. Hal ini menunjukkan preferensi masyarakat Arab Saudi terhadap kenyamanan dalam berkendara, terutama di kota besar yang padat. Dengan informasi ini, platform penjualan dan dealer sebaiknya memfokuskan pengadaan, pengelompokan, dan promosi pada unit bertransmisi otomatis. Ini menjawab pertanyaan *how* dan *why* terkait strategi inventaris dan penjualan.
#
# - Distribusi bahan bakar (`Fuel_Type`) menunjukkan bahwa lebih dari 95% mobil menggunakan bahan bakar bensin (gasoline), dengan hanya sebagian kecil (kurang dari 5%) merupakan mobil diesel atau hybrid. Fakta ini menunjukkan bahwa transisi ke kendaraan berbahan bakar alternatif masih sangat minim. Meskipun demikian, platform digital dan dealer dapat mulai menyiapkan segmentasi kecil untuk kendaraan hybrid sebagai langkah awal menuju arah keberlanjutan (*when* future transition expected), sambil terus memantau tren dan regulasi energi nasional.
#
# - Fitur `Origin` memperlihatkan bahwa sekitar 4.000 mobil berasal dari Saudi, sekitar 1.000 dari Gulf Arabic, dan sisanya dikategorikan sebagai “Other”. Informasi ini dapat digunakan dalam desain fitur filter, dengan menekankan kelebihan kendaraan lokal, misalnya lebih tahan cuaca gurun, untuk meningkatkan keyakinan pembeli dan mempercepat konversi.
#
# - Pada fitur `Options`, distribusi antara Standard (1.800 unit), Full (1.700 unit), dan Semi Full (1.400 unit) cukup merata. Ini menunjukkan bahwa kebutuhan konsumen cukup beragam, tidak hanya mencari fitur lengkap. Maka dari itu, platform sebaiknya menyediakan fitur pencarian berdasarkan tingkat kelengkapan fitur agar pengguna dapat menyesuaikan preferensinya dengan lebih cepat dan tepat, terutama untuk pelanggan dengan preferensi fitur spesifik (*how* pengalaman pencarian dapat ditingkatkan).
#
# - Fitur `Color` menunjukkan dominasi warna putih (lebih dari 2.000 unit), diikuti oleh silver, black, dan grey. Warna-warna lain seperti orange, green, dan yellow hanya mencakup kurang dari 2% total mobil. Ini menunjukkan *what* warna favorit konsumen. Warna netral seperti putih tidak hanya populer karena estetika, tetapi juga lebih tahan panas di iklim panas. Dealer disarankan untuk menjaga stok warna-warna netral ini dan menempatkannya di tampilan terdepan agar inventory dapat lebih cepat terserap pasar.
#
# - Tipe mobil (`Type`) sangat bervariasi, tetapi model seperti Accent, Camry, dan Hilux merupakan yang paling banyak muncul (masing-masing >150 unit). Dengan distribusi yang sangat panjang (long tail), fitur ini perlu diolah secara khusus saat pemodelan, misalnya dengan melakukan grouping tipe-tipe dengan jumlah sangat kecil ke dalam kategori “Other”. Hal ini akan meningkatkan efisiensi proses encoding dan mengurangi noise dalam model prediksi harga.
#
# Kesimpulan:
# Distribusi kategori memperlihatkan pola yang sangat tidak merata, dengan dominasi kuat pada beberapa nilai tertentu seperti `Toyota`, `Automatic`, `Gasoline`, dan `White`. Namun, pola ini memberikan insight yang kuat untuk menyusun strategi produk, inventory, dan rekomendasi berbasis data. Tindakan seperti penghapusan fitur redundant (`Region`), penguatan fitur filter (`Options`, `Origin`), dan fokus kampanye pada preferensi dominan (merek dan warna) akan memberikan dampak langsung terhadap efektivitas platform digital maupun strategi dealer di lapangan.

# %% [markdown]
# #### 3.7 Hubungan Harga dengan Fitur Kategorikal

# %%
# Create subplots for 2 columns
fig = make_subplots(rows=4, cols=2, subplot_titles=[
    'Distribusi Harga Berdasarkan Tipe Transmisi',
    'Distribusi Harga Berdasarkan Tipe Bahan Bakar',
    'Distribusi Harga Berdasarkan Asal Kendaraan',
    'Distribusi Harga Berdasarkan Opsi',
    'Distribusi Harga Berdasarkan Region',
    'Distribusi Harga Berdasarkan Make',
    'Distribusi Harga Berdasarkan Color',
    'Distribusi Harga Berdasarkan Tipe Kendaraan',
])

# Price vs Gear_Type
gear_type_fig = px.box(df[df['Price'] > 0], x='Gear_Type', y='Price', color='Gear_Type')
gear_type_fig.update_layout(xaxis_title='Gear_Type', yaxis_title='Price', xaxis_tickangle=45)
for trace in gear_type_fig['data']:
    trace.showlegend = False
    fig.add_trace(trace, row=1, col=1)

# Price vs Fuel_Type
fuel_type_fig = px.box(df[df['Price'] > 0], x='Fuel_Type', y='Price', color='Fuel_Type')
fuel_type_fig.update_layout(xaxis_title='Fuel_Type', yaxis_title='Price', xaxis_tickangle=45)
for trace in fuel_type_fig['data']:
    trace.showlegend = False
    fig.add_trace(trace, row=1, col=2)

# Price vs Origin
origin_fig = px.box(df[df['Price'] > 0], x='Origin', y='Price', color='Origin')
origin_fig.update_layout(xaxis_title='Origin', yaxis_title='Price', xaxis_tickangle=45)
for trace in origin_fig['data']:
    trace.showlegend = False
    fig.add_trace(trace, row=2, col=1)

# Price vs Options
options_fig = px.box(df[df['Price'] > 0], x='Options', y='Price', color='Options')
options_fig.update_layout(xaxis_title='Options', yaxis_title='Price', xaxis_tickangle=45)
for trace in options_fig['data']:
    trace.showlegend = False
    fig.add_trace(trace, row=2, col=2)

# Price vs Region
region_fig = px.box(df[df['Price'] > 0], x='Region', y='Price', color='Region')
region_fig.update_layout(xaxis_title='Region', yaxis_title='Price', xaxis_tickangle=45)
for trace in region_fig['data']:
    trace.showlegend = False
    fig.add_trace(trace, row=3, col=1)


# Price vs Make
make_fig = px.box(df[df['Price'] > 0], x='Make', y='Price', color='Make')
make_fig.update_layout(xaxis_title='Make', yaxis_title='Price', xaxis_tickangle=45)
for trace in make_fig['data']:
    trace.showlegend = False
    fig.add_trace(trace, row=3, col=2)

# Price vs color
color_fig = px.box(df[df['Price'] > 0], x='Color', y='Price', color='Color')
color_fig.update_layout(xaxis_title='Color', yaxis_title='Price', xaxis_tickangle=45)
for trace in color_fig['data']:
    trace.showlegend = False
    fig.add_trace(trace, row=4, col=1)

# Price vs Type (15 largest categories only)
# top_types = df['Type'].value_counts().nlargest(15).index
top_types = df['Type']

type_fig = px.box(df[df['Type'].isin(top_types) & (df['Price'] > 0)], x='Type', y='Price', color='Type')
type_fig.update_layout(xaxis_title='Type', yaxis_title='Price', xaxis_tickangle=45)
for trace in type_fig['data']:
    trace.showlegend = False
    fig.add_trace(trace, row=4, col=2)

# Update layout for the entire figure
fig.update_layout(height=1000, width=1500, title_text="Distribusi Harga Berdasarkan Berbagai Kategori")
fig.show()

# %% [markdown]
# - Distribusi harga berdasarkan `Gear_Type` menunjukkan bahwa mobil dengan transmisi otomatis memiliki harga median sekitar SAR 60.000, sedangkan transmisi manual memiliki median harga lebih rendah, sekitar SAR 35.000. Ini menunjukkan bahwa mobil otomatis secara konsisten dihargai lebih tinggi, dan ini dapat dimanfaatkan dealer untuk menargetkan segmen pasar premium dengan menyediakan lebih banyak unit otomatis di katalog utama mereka.
#
# - Fitur `Fuel_Type` memperlihatkan bahwa kendaraan hybrid memiliki distribusi harga tertinggi (median di atas SAR 100.000), jauh di atas kendaraan berbahan bakar bensin dan diesel. Walaupun populasinya masih sedikit (<5%), nilai pasar kendaraan hybrid secara signifikan lebih tinggi. Hal ini bisa dijadikan peluang untuk memasarkan unit hybrid sebagai opsi premium dan mengedukasi konsumen tentang efisiensi bahan bakar jangka panjang, terutama untuk segmen kelas menengah ke atas.
#
# - Distribusi harga berdasarkan `Origin` menunjukkan bahwa mobil yang berasal dari Gulf Arabic memiliki median harga sekitar SAR 80.000—lebih tinggi dibanding mobil lokal (Saudi) yang berada di sekitar SAR 60.000. Sementara itu, mobil dengan kategori `Unknown` memiliki median terendah, sekitar SAR 35.000. Temuan ini menjawab asal kendaraan dan pembelinya, dan menunjukkan pentingnya informasi asal kendaraan dalam membentuk persepsi nilai. Dealer disarankan untuk menampilkan asal kendaraan secara eksplisit dalam katalog dan memberikan highlight pada mobil Gulf yang cenderung premium.
#
# - Pada fitur `Options`, mobil dengan fitur lengkap (`Full`) memiliki harga median tertinggi (sekitar SAR 90.000), diikuti oleh `Semi Full` dan `Standard` di bawah SAR 60.000. Ini menjawab pertanyaan tingkat fitur menentukan harga dan dealer bisa menyesuaikan harga dengan kelengkapan Oleh karena itu, dalam strategi promosi, fitur-fitur seperti sunroof, leather seat, atau advanced infotainment dapat ditonjolkan untuk menaikkan persepsi nilai kendaraan.
#
# - Distribusi `Region` menunjukkan variasi harga yang luas antar wilayah, tetapi dengan tingkat keragaman yang cukup tinggi dan overlapping antar kota. Karena informasi ini sudah tercermin pada fitur `Origin`, dan tidak menambahkan nilai prediktif yang signifikan, maka `Region` diputuskan untuk tidak digunakan dalam pemodelan lanjutan. Hal ini menjawab *why* dan *how* dalam konteks feature selection.
#
# - Fitur `Make` menunjukkan adanya variasi harga yang sangat luas antar merek. Mobil premium seperti BMW dan Lexus memiliki outlier yang sangat tinggi (hingga > SAR 150.000), sementara merek seperti Hyundai dan Ford cenderung memiliki distribusi harga yang lebih terkonsentrasi di bawah SAR 80.000. Informasi ini dapat dimanfaatkan untuk segmentasi produk berdasarkan merek: dealer dapat membuat halaman khusus untuk mobil premium agar mempermudah pengguna dalam menyaring kendaraan dengan rentang harga tinggi.
#
# - Distribusi `Color` menunjukkan bahwa meskipun warna mobil tidak terlalu memengaruhi median harga secara drastis, warna tertentu seperti orange dan yellow memiliki persebaran harga yang sangat lebar. Hal ini dapat menunjukkan bahwa warna-warna tersebut lebih sering muncul di kendaraan edisi khusus atau langka. Untuk itu, disarankan agar warna tidak dijadikan fitur utama dalam penetapan harga, tetapi tetap dicantumkan secara informatif dalam deskripsi unit.
#
#
# - Terakhir, pada fitur `Type`, terlihat bahwa model seperti `Land Cruiser`, `G-Class`, dan `Escalade` memiliki median dan persebaran harga jauh di atas rata-rata, bahkan beberapa mendekati SAR 200.000. Sebaliknya, tipe seperti `Accent` atau `Yaris` memiliki median di bawah SAR 50.000. Informasi ini sangat penting untuk memetakan segmentasi harga berdasarkan model kendaraan. Untuk itu, sistem rekomendasi dapat memprioritaskan tampilan unit berdasarkan kategori tipe: luxury, economy, dan family car, untuk menyederhanakan proses pencarian dan mengarahkan pengguna ke preferensi harga yang sesuai.
#
# **Kesimpulan**:
# Distribusi harga berdasarkan fitur kategorikal mengungkapkan bahwa **faktor-faktor seperti tipe transmisi, bahan bakar, asal kendaraan, dan kelengkapan fitur memiliki hubungan yang jelas dengan nilai pasar kendaraan**. Sementara fitur seperti warna atau wilayah memiliki pengaruh yang lebih lemah dan bisa dipertimbangkan untuk dikesampingkan dalam modeling. Temuan ini dapat digunakan untuk menyusun strategi segmentasi produk dan personalisasi pengalaman pengguna berdasarkan preferensi dan daya beli konsumen.

# %% [markdown]
# ### Uji Statistik ANOVA pada Fitur Kategorikal terhadap Harga

# %% [markdown]
# Untuk melengkapi analisis visual sebelumnya, kita melakukan **Uji ANOVA (Analysis of Variance)** terhadap fitur-fitur kategorikal terhadap variabel target `Price`. Uji ini digunakan untuk mengetahui apakah **rata-rata harga antar kategori berbeda secara signifikan secara statistik**.
#
# Kenapa menggunakan ANOVA?
# - **ANOVA (Analysis of Variance)** cocok untuk mengetahui apakah setidaknya ada satu kategori dalam fitur kategorikal yang memiliki harga berbeda secara signifikan dibanding yang lain.
# - Kita sebelumnya telah mengetahui dari visualisasi bahwa terdapat variasi harga antar kategori, tetapi tanpa validasi statistik, kita tidak bisa menyimpulkan bahwa perbedaan tersebut tidak disebabkan oleh variasi acak.
# - Dengan ANOVA, kita mendapatkan **F-value** (seberapa besar variasi antar kelompok dibanding dalam kelompok) dan **p-value** (probabilitas bahwa perbedaan ini hanya karena kebetulan).
#
# Jika **p-value < 0.05**, maka kita menyimpulkan bahwa perbedaan harga antar kategori signifikan dan fitur tersebut relevan secara statistik terhadap prediksi harga.

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Ambil semua fitur kategorikal
categorical_features = df.select_dtypes(include='object').columns.tolist()

# Inisialisasi list hasil
anova_results = []
print("Signifikan bila p-value < 0.05")
print("Semakin besar F-value, semakin penting fitur tersebut")
# Loop untuk setiap fitur kategorikal
for col in categorical_features:
    model = ols(f'Price ~ C({col})', data=df).fit()
    anova = sm.stats.anova_lm(model, typ=2)
    f_val = anova['F'][0]
    p_val = anova['PR(>F)'][0]
    
    if p_val < 0.01:
        level = "Sangat Signifikan"
    elif p_val < 0.05:
        level = "Signifikan"
    elif p_val < 0.1:
        level = "Kurang Signifikan"
    else:
        level = "Tidak Signifikan"

    anova_results.append({
        'Feature': col,
        'F-value': round(f_val, 2),
        'p-value': p_val,
        'Significance': level
    })

# Tampilkan hasil sebagai DataFrame
anova_df = pd.DataFrame(anova_results).sort_values(by='F-value', ascending=False).reset_index(drop=True)
display(anova_df)
# Out:
# Signifikan bila p-value < 0.05
# Semakin besar F-value, semakin penting fitur tersebut
#      Feature  F-value        p-value       Significance
# 0    Options   316.99  1.710852e-127  Sangat Signifikan
# 1       Make   113.29  6.476225e-288  Sangat Signifikan
# 2       Type    83.90   0.000000e+00  Sangat Signifikan
# 3     Origin    52.42   3.763504e-33  Sangat Signifikan
# 4  Gear_Type    48.68   3.580217e-12  Sangat Signifikan
# 5      Color     7.52   8.192334e-16  Sangat Signifikan
# 6  Fuel_Type     4.34   1.310651e-02         Signifikan
# 7     Region     2.45   8.055761e-05  Sangat Signifikan

# %%
# Buat barplot F-value untuk visualisasi pengaruh fitur
plt.figure(figsize=(10, 6))
sns.barplot(data=anova_df, x='F-value', y='Feature', palette='viridis')
plt.title('F-value dari ANOVA per Fitur Kategorikal terhadap Harga')

plt.xlabel('F-value')
plt.ylabel('Fitur Kategorikal')
plt.tight_layout()
plt.show()

# %% [markdown]
# Uji statistik ANOVA yang dilakukan terhadap seluruh fitur kategorikal ini hasilnya menunjukkan bahwa seluruh fitur, termasuk `Color` dan `Region`, memiliki p-value < 0.05 yang berarti secara statistik **signifikan terhadap perbedaan harga**. Namun, fitur `Region` memiliki nilai F yang paling rendah (sekitar 4.26) di antara fitur lainnya. Hal ini menunjukkan bahwa meskipun perbedaannya signifikan secara statistik, **besarnya pengaruh atau kontribusi fitur `Region` terhadap variasi harga sangat kecil**, dan informasinya sudah cukup terwakili oleh fitur `Origin`. Selain itu, `Region` memiliki banyak kategori dan dapat menambah kompleksitas pada model ketika dilakukan encoding. Oleh karena itu, fitur `Region` akan dihapus dalam tahap preprocessing untuk menjaga kesederhanaan model.
#
# **Insight dan Rekomendasi**:
# Fitur-fitur seperti `Gear_Type`, `Options`, `Fuel_Type`, `Origin`, dan `Type` terbukti memiliki hubungan yang kuat dan signifikan secara statistik terhadap harga. Oleh karena itu, fitur-fitur ini disarankan untuk digunakan dalam tahap modeling prediktif harga mobil bekas. Sebaliknya, meskipun `Region` signifikan secara statistik, pengaruhnya terhadap harga sangat kecil secara praktikal dan bersifat redundan dengan `Origin`, sehingga fitur ini akan dihapus untuk menyederhanakan model dan menghindari duplikasi informasi.

# %% [markdown]
# #### 3.8 Hubungan Harga dengan Fitur Numerikal

# %%
# Create subplots for 2 columns
fig = make_subplots(rows=2, cols=2, subplot_titles=[
    'Distribusi Harga Berdasarkan Tahun',
    'Distribusi Harga Berdasarkan Mileage',
    'Distribusi Harga Berdasarkan Engine Size'
])

# Price vs Year
year_fig = px.scatter(df[df['Price'] > 0], x='Year', y='Price')
year_fig.update_layout(xaxis_title='Year', yaxis_title='Price', xaxis_tickangle=45)
for trace in year_fig['data']:
    trace.showlegend = False
    fig.add_trace(trace, row=1, col=1)

# Price vs Mileage 
mileage_fig = px.scatter(df[df['Price'] > 0], x='Mileage', y='Price')
mileage_fig.update_layout(xaxis_title='Mileage', yaxis_title='Price', xaxis_tickangle=45)
for trace in mileage_fig['data']:
    trace.showlegend = False
    fig.add_trace(trace, row=1, col=2)

# Price vs Engine_Size
region_fig = px.scatter(df[df['Price'] > 0], x='Engine_Size', y='Price')
region_fig.update_layout(xaxis_title='Engine_Size', yaxis_title='Price', xaxis_tickangle=45)
for trace in region_fig['data']:
    trace.showlegend = False
    fig.add_trace(trace, row=2, col=1)

# Update layout for the entire figure
fig.update_layout(height=500, width=1500, title_text="Distribusi Harga dengan Fitur Numerikal")
fig.show()

# %% [markdown]
# Berdasarkan visualisasi scatter plot terhadap fitur numerikal `Year`, `Mileage`, dan `Engine_Size`, kita dapat mengidentifikasi pola hubungan yang relevan terhadap variabel target `Price`.
#
# Secara umum, terlihat bahwa **semakin baru tahun pembuatan kendaraan, semakin tinggi harga pasar mobil tersebut**, terutama setelah tahun 2010 di mana terjadi lonjakan harga yang cukup signifikan. Hal ini menunjukkan bahwa `Year` memiliki hubungan positif terhadap harga mobil bekas, yang dapat dijelaskan oleh preferensi konsumen terhadap model-model terbaru yang dianggap lebih andal dan modern.
#
# Untuk fitur `Mileage`, tren yang tampak adalah **semakin tinggi jarak tempuh mobil, semakin rendah harga jualnya**. Sebagian besar mobil dengan harga di atas SAR 100.000 memiliki mileage yang cenderung rendah (di bawah 150.000 km). Ini konsisten dengan persepsi umum bahwa kendaraan dengan jarak tempuh rendah lebih diminati karena dianggap memiliki masa pakai dan performa yang lebih baik.
#
# Fitur `Engine_Size` juga memperlihatkan **korelasi positif moderat terhadap harga**, walaupun terdapat penyebaran harga yang lebih besar. Mobil dengan ukuran mesin di atas 4.0L cenderung memiliki variasi harga yang tinggi, termasuk beberapa di antaranya yang masuk dalam kategori kendaraan mewah seperti SUV premium atau sportscar.
#
# **Insight dan Rekomendasi:**
# Mayoritas kendaraan dengan harga tinggi berasal dari mobil keluaran terbaru (di atas tahun 2015), berjarak tempuh rendah (di bawah 150.000 km), dan memiliki ukuran mesin yang lebih besar (di atas 3.0L). Oleh karena itu, dalam tahap pemodelan harga mobil bekas, fitur `Year`, `Mileage`, dan `Engine_Size` sangat penting untuk dipertahankan karena secara jelas menunjukkan pengaruh langsung dan kuantitatif terhadap nilai pasar kendaraan. Tim bisnis dapat menggunakan temuan ini untuk mengarahkan strategi penetapan harga yang lebih akurat berdasarkan tahun produksi dan spesifikasi teknis utama dari unit yang dijual.

# %% [markdown]
# ## 4. Data Preprocessing

# %% [markdown]
# ### 4.1 Data Cleaning Tambahan

# %% [markdown]
# rapihkan nilai pada kolom Origin dengan mengubah nilai "unknown" menjadi "other" saja.

# %%
# 1. Mengecek jumlah nilai unik sebelum penggantian
print("Nilai unik pada kolom 'Origin' sebelum penggantian:")
print(df['Origin'].value_counts())
print("Jumlah nilai unik:", df['Origin'].nunique())
# Out:
# Nilai unik pada kolom 'Origin' sebelum penggantian:
# Origin
# Saudi          2718
# Gulf Arabic     482
# Other           373
# Unknown          16
# Name: count, dtype: int64
# Jumlah nilai unik: 4

# %%
# 2. Mengganti nilai 'unknown' menjadi 'other'
df['Origin'] = df['Origin'].replace('Unknown', 'Other')

#visualisasikan kolom 'Origin' setelah diubah
fig = px.histogram(df, x='Origin', title='Distribusi Origin Setelah Perubahan')
fig.update_layout(xaxis_title='Origin', yaxis_title='Count')
fig.show()

# %% [markdown]
# Karena baris dengan price 0 dihapus, itu artinya kolom negotiable hanya memiliki nilai FALSE, karena hanya memiliki 1 jenis maka kolom ini bisa kita hapuskan saja.

# %%
df.drop(columns=['Negotiable'], inplace=True)

# %%
df.to_csv("UsedCarsSA_Very_Clean_EN.csv", index=False)

# %%
df_clean = df.copy()

# %% [markdown]
# #### 4.2 Feature Selection

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3589 entries, 1 to 5552
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         3589 non-null   object
#  1   Type         3589 non-null   object
#  2   Year         3589 non-null   int64
#  3   Origin       3589 non-null   object
#  4   Color        3589 non-null   object
#  5   Options      3589 non-null   object
#  6   Engine_Size  3589 non-null   float64
#  7   Fuel_Type    3589 non-null   object
#  8   Gear_Type    3589 non-null   object
#  9   Mileage      3589 non-null   int64
#  10  Region       3589 non-null   object
#  11  Price        3589 non-null   int64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 364.5+ KB

# %%
df.describe()
# Out:
#               Year  Engine_Size        Mileage          Price
# count  3589.000000  3589.000000    3589.000000    3589.000000
# mean   2015.088604     3.227724  125504.690443   79653.274450
# std       4.533593     1.485537   97577.196819   64352.224276
# min    1978.000000     1.000000     100.000000    5000.000000
# 25%    2014.000000     2.000000   53000.000000   38000.000000
# 50%    2016.000000     2.700000  104000.000000   60000.000000
# 75%    2018.000000     4.000000  183000.000000   98000.000000
# max    2021.000000     9.000000  432000.000000  435000.000000

# %% [markdown]
# #### 4.3 Feature Engineering

# %%
#drop Region
df_clean.drop(columns=['Region'], inplace=True)

# %% [markdown]
# ## 5. Modelling

# %% [markdown]
# ### **Train-Test Split Sebelum Encoding & Scaling**
#
# Untuk menghindari **information leakage**, proses **train-test split** dilakukan terlebih dahulu sebelum encoding dan scaling. Hal ini memastikan bahwa model tidak "mengintip" informasi dari data test selama pelatihan.
#
# ---
#
# ###  **Encoding**
#
# #### a. **Target Encoding**
#
# Digunakan untuk kolom kategorikal dengan banyak kategori unik: `['Type', 'Color', 'Make']`. TargetEncoder menggunakan nilai target (`Price`) untuk membantu encoding, sehingga hanya di-*fit* pada `X_train` dengan `y_train`.
#
# #### b. **Ordinal Encoding**
#
# Digunakan untuk fitur kategorikal dengan sedikit kategori unik: `['Options', 'Origin', 'Gear_Type', 'Fuel_Type']`.
#
# ---
#
# ###  **Feature Scaling**
#
# Digunakan `StandardScaler` dari `sklearn` untuk menormalisasi fitur numerik: `['Mileage', 'Year', 'Engine_Size']`, agar fitur berada dalam skala yang seragam.
#
# ---
#
# ### **Model Regresi yang Digunakan**
#
# Beberapa algoritma regresi digunakan untuk membandingkan performa prediksi harga mobil bekas:
#
# #### Base Models
# - **Linear Regression:**
#   Mengestimasikan hubungan linier antara fitur dan target dengan mencari koefisien yang meminimalkan error kuadrat, ideal untuk hubungan yang linear dan data bebas multikolinearitas serta outlier ekstrim.
#
# - **KNN Regressor:**
#   Menghitung nilai target berdasarkan rata-rata nilai dari 'k' tetangga terdekat dalam ruang fitur; efektif untuk pola lokal, namun sensitif terhadap skala fitur dan data berdimensi tinggi.
#
# - **Decision Tree Regressor:**
#   Membagi data secara rekursif dengan membuat keputusan berdasarkan nilai fitur, sehingga menghasilkan struktur pohon yang memetakan fitur ke target; mampu menangkap hubungan non-linier namun rentan terhadap overfitting jika tidak dikendalikan.
#
# - **Ridge, Lasso, dan Elastic Net:**
#   Merupakan varian Linear Regression dengan penambahan regularisasi (L2 untuk Ridge, L1 untuk Lasso, dan kombinasi keduanya untuk Elastic Net) yang membantu mengatasi multikolinearitas dan mencegah overfitting dengan mengurangi kompleksitas model.
#
# #### Ensemble Models
# - **Random Forest Regressor:**
#   Menggabungkan prediksi dari banyak decision tree yang dilatih secara acak pada subset data dan fitur (bagging) untuk mengurangi variansi dan meningkatkan stabilitas prediksi.
#
# - **AdaBoost Regressor:**
#   Mengadaptasi bobot data secara iteratif, sehingga model lebih fokus pada contoh yang sulit diprediksi; membantu meningkatkan akurasi dengan mengurangi bias, namun bisa terpengaruh oleh outlier.
#
# - **Gradient Boosting Regressor:**
#   Membangun model secara berurutan dengan setiap pohon mencoba memperbaiki kesalahan residual dari model sebelumnya; efektif menangkap pola kompleks, namun memerlukan tuning agar tidak overfit.
#
# - **Xtreme Gradient Boosting (XGBoost):**
#   Versi yang dioptimasi dari gradient boosting yang menambahkan regularisasi dan teknik komputasi efisien, sehingga cocok untuk dataset besar dan kompleks dengan kinerja tinggi bila telah dituning dengan baik.
#
# #### Model Dapat Dipercaya (Akurat) Jika:
# - **Data Training Representatif:**
#   Data yang digunakan untuk melatih model mencakup seluruh variabilitas yang mungkin ditemui di dunia nyata, sehingga model dapat menangani kasus baru dengan karakteristik serupa.
#
# - **Asumsi Model Terpenuhi:**
#   Misalnya, untuk Linear Regression, hubungan antara fitur dan target bersifat linier; untuk model tree-based, data cukup bersih dari noise ekstrim.
#
# - **Validasi dan Cross-Validation Konsisten:**
#   Metrik performa (seperti RMSE, MAE, dan R²) menunjukkan performa yang baik dan konsisten antara data pelatihan, validasi, dan test set, serta analisis residual menunjukkan error yang tersebar acak.
#
# - **Data Baru Sesuai dengan Data Training:**
#   Input baru yang akan diprediksi memiliki karakteristik (rentang nilai, distribusi) yang mirip dengan data yang digunakan untuk melatih model.
#
# #### Model Tidak Dapat Dipercaya (Kurang Akurat) Jika:
# - **Data Tidak Representatif atau Out-of-Distribution:**
#   Data baru yang memiliki pola, rentang, atau distribusi yang sangat berbeda dari data training, seperti data dengan outlier ekstrim atau kondisi yang belum pernah terjadi selama pelatihan.
#
# - **Overfitting atau Underfitting Terjadi:**
#   Model yang terlalu kompleks mungkin menghafal noise pada data pelatihan (overfitting) atau model yang terlalu sederhana tidak menangkap pola penting (underfitting), sehingga performa di dunia nyata menurun.
#
# - **Data Bermasalah:**
#   Data yang banyak mengandung noise, missing values, atau kesalahan pencatatan dapat mengurangi akurasi prediksi model.
#
# #### Data yang Membuat Model Bisa Dipercaya dan Tidak dipercaya
#
# - **Data yang Membuat Model Bisa Dipercaya (Akurat):**
#   - Data yang sudah melalui proses pembersihan dan preprocessing (misalnya, imputasi missing values, scaling, encoding) dengan konsisten.
#   - Data yang mencakup rentang nilai dan distribusi yang sama dengan data training.
#   - Data dengan sedikit noise dan outlier yang sudah diatasi melalui teknik seperti IQR.
#
# - **Data yang Membuat Model Tidak Dapat Dipercaya (Kurang Akurat):**
#   - Data yang memiliki fitur atau pola yang berbeda secara signifikan dibandingkan dengan data training (misalnya, perubahan tren pasar yang belum tercermin di data lama).
#   - Data yang mengandung banyak outlier, noise, atau missing values yang tidak ditangani dengan baik.
#   - Data dari segmen yang jarang atau tidak terwakili dalam data training, sehingga model kesulitan memberikan prediksi yang akurat.
#
# - **Base models** memberikan gambaran awal dengan pendekatan algoritma yang berbeda, yang membantu memahami karakteristik dasar data.
# - **Ensemble models** memanfaatkan kekuatan kolektif dari beberapa model untuk meningkatkan akurasi, mengurangi overfitting, dan menghasilkan prediksi yang lebih robust.
#
# ---
# ### Evaluasi Model Menggunakan RMSE, MAE, MAPE, dan R²
#
# Dalam proyek prediksi harga mobil bekas, digunakan **4 metrik evaluasi** untuk menilai performa model, yaitu RMSE, MAE, MAPE, dan R². Di bawah ini dijelaskan cara kerja masing-masing metrik dan bagaimana kaitannya dengan aspek bisnis:
#
# #### 1. Root Mean Squared Error (RMSE)
# - **Definisi:**
#   RMSE dihitung sebagai akar dari rata-rata kuadrat selisih antara nilai prediksi dan nilai aktual, yaitu:
#   $$
# RMSE = \sqrt{\frac{1}{n} \sum_{i=1}^{n} (y_i - \hat{y}_i)^2}
# $$
# - **Cara Kerja:**
#   Dengan mengkuadratkan selisih, RMSE memberikan penalti lebih besar terhadap error yang besar; kemudian, dengan mengakarnya, hasilnya dikembalikan ke satuan yang sama dengan target.
# - **Kelebihan:**
#   - Sensitif terhadap error besar, sehingga mengungkapkan jika ada prediksi yang jauh meleset.
#   - Satuan output sama dengan target (misalnya, rupiah), memudahkan interpretasi.
# - **Hubungan dengan Aspek Bisnis:**
#   Dalam konteks bisnis, kesalahan besar dalam prediksi harga dapat mengakibatkan keputusan yang merugikan (misalnya, overpricing atau underpricing mobil). RMSE membantu mengidentifikasi dan meminimalkan dampak kesalahan ekstrim tersebut sehingga keputusan penetapan harga lebih andal.
#
# #### 2. Mean Absolute Error (MAE)
# - **Definisi:**
#   MAE adalah rata-rata selisih absolut antara prediksi dan nilai aktual:
#   $$
# MAE = \frac{1}{n} \sum_{i=1}^{n} \left| y_i - \hat{y}_i \right|
# $$
# - **Cara Kerja:**
#   MAE menghitung nilai kesalahan tanpa memperhatikan arah (positif atau negatif) dan memberikan gambaran rata-rata seberapa jauh prediksi menyimpang dari nilai sebenarnya.
# - **Kelebihan:**
#   - Mudah diinterpretasikan karena memberikan nilai error dalam satuan yang sama.
#   - Kurang sensitif terhadap outlier dibandingkan RMSE.
# - **Hubungan dengan Aspek Bisnis:**
#   MAE memberikan pandangan yang realistis tentang seberapa besar rata-rata selisih prediksi dengan harga sebenarnya. Ini sangat berguna dalam penganggaran dan perencanaan keuangan karena menyampaikan perkiraan kerugian atau keuntungan secara rata-rata dalam transaksi harga mobil.
#
# #### 3. Mean Absolute Percentage Error (MAPE)
# - **Definisi:**
#   MAPE mengukur kesalahan rata-rata dalam bentuk persentase dari nilai aktual:
#   $$
# MAPE = \frac{100\%}{n} \sum_{i=1}^{n} \left| \frac{y_i - \hat{y}_i}{y_i} \right|
# $$
# - **Cara Kerja:**
#   Dengan menghitung error relatif terhadap nilai aktual, MAPE menghasilkan nilai persentase yang menunjukkan seberapa besar kesalahan dibandingkan dengan nilai yang diharapkan.
# - **Kelebihan:**
#   - Hasil berupa persentase memudahkan pemahaman oleh pemangku kepentingan non-teknis.
#   - Memungkinkan perbandingan antar model dan kondisi pasar yang berbeda.
# - **Hubungan dengan Aspek Bisnis:**
#   Dalam bisnis, MAPE memudahkan analisis risiko dan profitabilitas karena menunjukkan error dalam konteks persentase. Misalnya, mengetahui bahwa model memiliki error 5% dapat langsung diterjemahkan ke dalam estimasi keakuratan harga dan potensi margin keuntungan atau kerugian.
#
# #### 4. R-squared (R²)
# - **Definisi:**
#   R² mengukur proporsi variabilitas target yang dapat dijelaskan oleh model, dihitung dengan:
#   $$
# R^2 = 1 - \frac{\sum_{i=1}^{n} (y_i - \hat{y}_i)^2}{\sum_{i=1}^{n} (y_i - \bar{y})^2}
# $$
#
# - **Cara Kerja:**
#   R² membandingkan total varians yang dijelaskan oleh model dengan total varians dalam data aktual. Nilai mendekati 1 berarti model dapat menjelaskan sebagian besar variabilitas.
# - **Kelebihan:**
#   - Memberikan indikasi seberapa baik model menangkap pola dan hubungan dalam data.
#   - Mudah dipahami, karena nilainya berkisar antara 0 (tidak ada penjelasan) hingga 1 (penjelasan sempurna).
# - **Hubungan dengan Aspek Bisnis:**
#   R² memberikan gambaran kepercayaan terhadap model dalam menjelaskan harga mobil. Nilai yang tinggi menunjukkan bahwa model dapat diandalkan dalam membuat prediksi, sehingga strategi bisnis, seperti penetapan harga atau evaluasi pasar, dapat dilakukan dengan keyakinan lebih tinggi.
#
# ---
#
# Dengan menggunakan kombinasi keempat metrik ini, kita mendapatkan gambaran yang komprehensif tentang performa model. Secara bisnis, hal ini penting karena membantu memastikan bahwa:
# - **Kesalahan Prediksi** tidak terlalu besar sehingga dapat mengganggu profitabilitas.
# - **Konsistensi dan Stabilitas** model dapat diandalkan untuk keputusan strategis.
# - **Perbandingan Kinerja** antar model dapat dilakukan secara objektif dengan melihat dampak kesalahan dalam konteks nilai uang dan risiko bisnis.
#
# Dengan mengkombinasikan keempat metrik evaluasi ini, kita mendapatkan gambaran yang komprehensif tentang performa model:
# - **RMSE** dan **MAE** menilai kesalahan absolut dengan cara yang berbeda (sensitivitas terhadap outlier).
# - **MAPE** menyajikan kesalahan dalam bentuk persentase, memudahkan interpretasi terutama jika skala harga sangat bervariasi.
# - **R²** menunjukkan seberapa baik model dapat menangkap variabilitas data.
#
# Pendekatan ini memungkinkan perbandingan yang adil antara 6 base model dan 4 ensemble model, sehingga model akhir yang dipilih tidak hanya akurat tetapi juga konsisten dan relevan dengan kebutuhan bisnis dalam prediksi harga mobil bekas.

# %%
import numpy as np
import pandas as pd
import category_encoders as ce
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# Daftar kolom untuk encoding dan scaling
target_encoded_features = ['Type', 'Color', 'Make']  
ordinal_features = ['Options', 'Origin', 'Gear_Type', 'Fuel_Type']
numerical_features = ['Mileage', 'Year', 'Engine_Size']

# Pisahkan fitur dan target
X = df_clean.drop('Price', axis=1)
y = df_clean['Price']

# Split data sebelum encoding dan scaling
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

target_encoder = ce.TargetEncoder(cols=target_encoded_features)
X_train = target_encoder.fit_transform(X_train, y_train)
X_test = target_encoder.transform(X_test)

# Ordinal Encoding (fit hanya pada X_train)
ordinal_encoder = ce.OrdinalEncoder(cols=ordinal_features)
X_train = ordinal_encoder.fit_transform(X_train)
X_test = ordinal_encoder.transform(X_test)

# Scaling (fit hanya pada X_train)
scaler = StandardScaler()
X_train[numerical_features] = scaler.fit_transform(X_train[numerical_features])
X_test[numerical_features] = scaler.transform(X_test[numerical_features])

# Lihat isinya X_train
X_train
# Out:
#               Make           Type      Year  Origin          Color  Options  \
# 3907  58488.798024   58488.798024  0.204702       1   79885.923315        1
# 1392  87676.881072   87676.881072 -0.014589       2   55747.843230        1
# 198   83055.444444   73238.231715 -0.233880       1   79885.923315        2
# 1866  83055.444444   92881.731830  0.204702       1   79885.923315        1
# 1374  83055.444444  156654.461030  0.643285       1   79885.923315        1
# ...            ...            ...       ...     ...            ...      ...
# 1400  67472.614612   81214.191788  0.204702       2   79885.923315        1
# 1607  56834.810345   65076.538986  0.423993       1   79125.868094        2
# 1034  56834.810345   65076.538986 -1.111045       2  101509.136213        3
# 5393  56834.810345   61405.348795  1.301158       1   79125.868094        3
# 4732  45517.269531   61272.122879 -0.014589       1   79885.923315        1
#
#       Engine_Size  Fuel_Type  Gear_Type   Mileage
# ...

# %%
# Daftar model
models = {
    'Linear Regression': LinearRegression(),
    'Ridge Regression': Ridge(alpha=1.0),
    'Lasso Regression': Lasso(alpha=0.1),
    'Elastic Net': ElasticNet(alpha=1.0, l1_ratio=0.5, random_state=42),
    'KNN Regressor': KNeighborsRegressor(n_neighbors=5),
    'Decision Tree Regressor': DecisionTreeRegressor(random_state=42),
    'Random Forest Regressor': RandomForestRegressor(n_estimators=100, random_state=42),
    'Gradient Boosting Regressor': GradientBoostingRegressor(random_state=42),
    'Support Vector Regressor': SVR(),
    'XGBoost Regressor': XGBRegressor(n_estimators=100, random_state=42, verbosity=0)
}

# Simpan hasil evaluasi
results = []

for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    r2 = r2_score(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_test, y_pred)
    mape = mean_absolute_percentage_error(y_test, y_pred)
    
    results.append({
        'Model': name,
        'RMSE': rmse,
        'MAE': mae,
        'MAPE': mape,
        'R2': r2
    })

# Hasil evaluasi
results_df = pd.DataFrame(results).set_index('Model')
results_df = results_df.sort_values(by='MAPE', ascending=True)
results_df
# Out:
#                                      RMSE           MAE      MAPE        R2
# Model
# Random Forest Regressor      15917.275460   9136.427231  0.127502  0.943010
# XGBoost Regressor            15447.184857   8981.706055  0.127836  0.946326
# Gradient Boosting Regressor  17784.346924  10500.009762  0.149831  0.928856
# Decision Tree Regressor      20840.913302  12066.293872  0.168541  0.902299
# Elastic Net                  34662.383843  20636.504941  0.330495  0.729741
# KNN Regressor                34835.392288  20540.004735  0.330908  0.727036
# Ridge Regression             32843.379829  20185.845157  0.385585  0.757362
# Lasso Regression             32843.575089  20187.475940  0.385696  0.757359
# Linear Regression            32843.581172  20187.524085  0.385697  0.757359
# Support Vector Regressor     70558.552234  44045.941985  0.630841 -0.119858

# %% [markdown]
# ###  Analisis Hasil Evaluasi (`results_df`)
#
# Tabel hasil evaluasi model disimpan dalam `results_df`, yang berisi metrik evaluasi seperti RMSE, MAE, MAPE, dan R² untuk setiap model regresi. Tabel ini **diurutkan berdasarkan nilai MAPE terkecil** terlebih dahulu, karena MAPE (Mean Absolute Percentage Error) adalah salah satu indikator penting dalam memprediksi harga mobil bekas, terutama untuk interpretasi bisnis.
#
# ---
#
# ###  Penjelasan MAPE
#
# **MAPE** mengukur rata-rata kesalahan prediksi dalam bentuk **persentase terhadap nilai aslinya**. Semakin kecil nilai MAPE, semakin akurat model tersebut.
#
# Sebagai contoh:
#
# * Nilai MAPE sebesar `0.1275` berarti bahwa model melakukan kesalahan prediksi sebesar **12.75%** secara rata-rata dari nilai sebenarnya.
# * Dalam konteks prediksi **harga mobil bekas**, ini berarti jika harga mobil sebenarnya adalah Rp 100.000.000, maka prediksi model bisa meleset sekitar **Rp 12.750.000** rata-ratanya.
#
# ---
#
# ###  Model Terbaik Berdasarkan MAPE
#
# Dari hasil `results_df`, dua model dengan performa terbaik berdasarkan nilai **MAPE terkecil** adalah:
#
# | Model                 | MAPE     |
# | --------------------- | -------- |
# | **Random Forest**     | 0.127502 |
# | **XGBoost Regressor** | 0.127836 |
#
# * **Random Forest** memiliki MAPE **12.7502%**
# * **XGBoost Regressor** memiliki MAPE **12.7836%**
#
#  **Selisih MAPE antara keduanya adalah sekitar `0.000334` atau 0.0334%**, yang sangat kecil.
#
# ---
#
# ###  Langkah Selanjutnya: Hyperparameter Tuning
#
# Karena kedua model memiliki performa yang sangat mirip, maka pada tahap selanjutnya akan dilakukan **hyperparameter tuning** untuk:
#
# * Mengoptimalkan kinerja masing-masing model
# * Mencari tahu apakah dengan penyetelan parameter yang tepat, salah satu dari model tersebut bisa secara signifikan mengungguli yang lainnya
#
# Langkah ini penting untuk memastikan bahwa model yang dipilih benar-benar memberikan prediksi harga mobil bekas yang paling akurat dan stabil.

# %% [markdown]
# ## 6. Hyperparameter Tuning (Menggunakan Optuna)

# %% [markdown]
# ### **Alasan Menggunakan Optuna**
#
# Pada tahap tuning pertama akan menggunakan **Optuna** sebagai metode optimasi hyperparameter, dibandingkan pendekatan tradisional seperti **Grid Search** maupun **Randomized Search CV**.
#
# Alasan utama memilih **Optuna**:
#
# *  **Efisiensi Eksplorasi Ruang Parameter**: Optuna menggunakan pendekatan **Bayesian optimization (TPE Sampler)** yang lebih cerdas dalam memilih kombinasi parameter berdasarkan hasil sebelumnya.
# *  **Lebih Cepat dan Lebih Adaptif**: Optuna secara otomatis mengevaluasi parameter yang menjanjikan, menghemat waktu dibanding grid search yang brute-force.
# *  **Lebih Akurat** dalam menemukan kombinasi optimal dibanding RandomizedSearchCV yang hanya mengambil kombinasi secara acak.
#
# ---
#
# ### **K-Fold Cross Validation dengan Repeats**
#
# Menggunakan metode validasi silang **Repeated K-Fold Cross Validation** (`RepeatedKFold`) dengan 5 folds dan 3 pengulangan.
#
# **Alasan menggunakan RepeatedKFold**:
#
# *  Memberikan estimasi yang lebih **stabil dan robust** dengan mengurangi variansi dari satu kali pembagian data.
# *  Kombinasi folds yang beragam meningkatkan representasi generalisasi model.
#
# ---
#
# ### **Parameter yang Dituning**
#
# Optuna dikonfigurasi untuk mengeksplorasi kombinasi hyperparameter berikut:
#
# | Parameter           | Deskripsi                                       |
# | ------------------- | ----------------------------------------------- |
# | `n_estimators`      | Jumlah pohon dalam ensemble (100–500)           |
# | `max_depth`         | Maksimum kedalaman pohon (5–30)                 |
# | `min_samples_split` | Minimum jumlah sampel untuk split (2–10)        |
# | `min_samples_leaf`  | Minimum sampel pada daun pohon (1–10)           |
# | `max_features`      | Metode pemilihan fitur (`None`, `sqrt`, `log2`) |
# | `bootstrap`         | Apakah menggunakan bootstrap sampling           |
#
# ---
#
# ### **Tujuan Optimasi**
#
# Tujuan dari tuning ini adalah **meminimalkan nilai MAPE** (Mean Absolute Percentage Error), karena MAPE memberikan indikasi langsung dalam bentuk persentase kesalahan prediksi harga mobil bekas.
#
# Dengan pendekatan ini, model dievaluasi berdasarkan performa rata-rata dari 15 fold (5 fold × 3 repeat), memastikan hasil tuning yang lebih reliabel.
#
# ---
#
# ### **Jumlah Eksperimen (Trials)**
#
# Menjalankan **50 trials** menggunakan **Optuna**, artinya Optuna mengevaluasi 50 kombinasi parameter untuk mencari kombinasi dengan MAPE terkecil.
#
# ---
#
# ### **Hasil Tuning**
#
# * Parameter terbaik ditemukan oleh Optuna ditampilkan melalui `study.best_params`.
# * Model Random Forest terbaik dilatih ulang menggunakan kombinasi ini dan dievaluasi pada data uji (`X_test`).
# * Performanya kemudian ditambahkan ke `results_df` sebagai:
#
# ```
# Tuned Random Forest Regressor (Optuna)
# ```
#
# ###  **Visualisasi Konvergensi MAPE**
#
# Grafik di bawah menunjukkan bagaimana nilai MAPE berevolusi di tiap trial, memperlihatkan bagaimana Optuna mengeksplorasi ruang parameter untuk memperbaiki hasil:
#
# ---
#
# ###  **Perbandingan Hasil**
#
# Setelah proses tuning, `results_df` kembali diurutkan berdasarkan **MAPE terkecil**, untuk melihat apakah hasil tuning berhasil mengungguli model sebelumnya.

# %%
# Untuk menginstall optuna dan visualisasinya
#!pip install optuna
#!pip install optuna[visualization]

# %%
import optuna
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score, RepeatedKFold
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error, mean_absolute_error, r2_score, make_scorer
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time

start_time = time.time()

cv = RepeatedKFold(n_splits=5, n_repeats=3, random_state=42)

# Fungsi objective untuk Optuna (minimisasi MAPE)
def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 500),
        'max_depth': trial.suggest_int('max_depth', 5, 30),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 10),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
        'max_features': trial.suggest_categorical('max_features', [None, 'sqrt', 'log2']),
        'bootstrap': trial.suggest_categorical('bootstrap', [True, False]),
    }

    model = RandomForestRegressor(random_state=42, n_jobs=-1, **params)

    # Gunakan cross-validation untuk menghitung MAPE
    score = cross_val_score(
        model, X_train, y_train,
        cv=cv,
        scoring=make_scorer(mean_absolute_percentage_error),
        n_jobs=-1
    )

    mape_mean = score.mean()
    trial.set_user_attr("mape", mape_mean)

    return mape_mean

# Jalankan optimisasi
sampler = optuna.samplers.TPESampler(seed=3)
study = optuna.create_study(direction="minimize", sampler=sampler)
study.optimize(objective, n_trials=50, show_progress_bar=True)

# Ambil model terbaik dan latih
best_params = study.best_params
best_rf = RandomForestRegressor(random_state=42, n_jobs=-1, **best_params)
best_rf.fit(X_train, y_train)
y_pred = best_rf.predict(X_test)

# Evaluasi performa
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)

# Tambahkan ke results_df
results_df.loc['Tuned Random Forest Regressor (Optuna)'] = [rmse, mae, mape, r2]

# Cetak hasil
print("Best parameters found by Optuna:", best_params)
print("Best cross-validation MAPE from Optuna:", study.best_value)

end_time = time.time()
duration = end_time - start_time
print(f"Hyperparameter tuning selesai dalam {duration:.2f} detik ({duration/60:.2f} menit)")

# Plot konvergensi MAPE per trial
mapes = [t.user_attrs["mape"] for t in study.trials if "mape" in t.user_attrs]
plt.plot(mapes, marker='o')
plt.xlabel("Trial")
plt.ylabel("MAPE")
plt.title("MAPE per Trial")
plt.grid(True)
plt.show()

# Urutkan hasil akhir
results_df = results_df.sort_values(by='MAPE', ascending=True)
results_df
# Out:
# [I 2025-05-23 17:19:44,642] A new study created in memory with name: no-name-b782a6cb-d0af-4a39-9db3-6852d59b3c53
# Best trial: 0. Best value: 0.221656:   2%|▏         | 1/50 [00:10<08:27, 10.35s/it]
# [I 2025-05-23 17:19:54,984] Trial 0 finished with value: 0.22165595739024005 and parameters: {'n_estimators': 320, 'max_depth': 23, 'min_samples_split': 4, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 0 with value: 0.22165595739024005.
# Best trial: 0. Best value: 0.221656:   4%|▍         | 2/50 [00:15<05:38,  7.05s/it]
# [I 2025-05-23 17:19:59,718] Trial 1 finished with value: 0.3420275348946398 and parameters: {'n_estimators': 276, 'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 0 with value: 0.22165595739024005.
# Best trial: 0. Best value: 0.221656:   6%|▌         | 3/50 [00:16<03:34,  4.56s/it]
# ...

# %% [markdown]
# ###  Performa Model Hasil Tuning
#
# Setelah dilakukan tuning hyperparameter menggunakan **Optuna**, model **Random Forest Regressor** yang telah dituning berhasil menunjukkan peningkatan performa:
#
# | Model                            | MAPE     | MAE     | RMSE     | R²     |
# | -------------------------------- | -------- | ------- | -------- | ------ |
# | **Tuned Random Forest (Optuna)** | 0.124392 | 8922.45 | 15589.64 | 0.9453 |
# | Random Forest (sebelum tuning)   | 0.127502 | 9136.43 | 15917.28 | 0.9430 |
#
# * Nilai **MAPE turun dari 12.75% menjadi 12.44%**, menunjukkan bahwa kesalahan prediksi model terhadap harga mobil bekas menjadi lebih kecil secara rata-rata.
# * Ini menunjukkan bahwa **tuning berhasil meningkatkan akurasi model** walaupun selisih peningkatannya tidak besar (sekitar 0.31%).
#
# ---
#
# ###  Mengapa Nilai MAPE dari `study.best_value` Berbeda dengan MAPE di `results_df`?
#
# Perbedaan ini terjadi karena:
#
# * **`study.best_value` dihitung dari nilai rata-rata MAPE hasil cross-validation (RepeatedKFold)** selama proses tuning.
# * **`results_df["MAPE"]` dihitung berdasarkan evaluasi akhir model pada data test (`X_test`)**, yaitu data yang benar-benar tidak dilihat oleh model selama proses tuning.
#
# Dengan kata lain:
#
# * `study.best_value` → *indikasi kinerja rata-rata model saat tuning*
# * `results_df` → *indikasi kinerja aktual model pada data baru (real performance)*
#
#  **Kesimpulan:**
# Meskipun `study.best_value` terlihat lebih besar, **evaluasi akhir pada `results_df` yang lebih penting**, karena menunjukkan performa model ketika dihadapkan pada data yang tidak pernah dilatih atau divalidasi sebelumnya.
#
# ---
#
# ###  Parameter Terbaik dari Optuna
#
# ```python
# {'n_estimators': 484,
#  'max_depth': 26,
#  'min_samples_split': 5,
#  'min_samples_leaf': 2,
#  'max_features': None,
#  'bootstrap': True}
# ```
#
# Parameter ini adalah kombinasi yang secara signifikan mampu menurunkan **MAPE test set** menjadi **12.44%**, lebih baik dibandingkan model Random Forest awal.

# %% [markdown]
# ### **Parameter yang Dituning Untuk Model XGB**
#
# Berikut adalah daftar parameter yang dieksplorasi dalam proses tuning untuk model **XGBoost Regressor**:
#
# | Parameter          | Deskripsi                                             |
# | ------------------ | ----------------------------------------------------- |
# | `n_estimators`     | Jumlah boosting rounds (100–500)                      |
# | `max_depth`        | Maksimum kedalaman pohon (3–12)                       |
# | `learning_rate`    | Tingkat pembelajaran (0.01–0.3)                       |
# | `subsample`        | Rasio data yang digunakan per tree (0.6–1.0)          |
# | `colsample_bytree` | Rasio fitur yang dipilih per tree (0.6–1.0)           |
# | `gamma`            | Minimum loss reduction untuk split (0–5)              |
# | `min_child_weight` | Minimum sum dari instance weight di daun pohon (1–20) |
# | `reg_alpha`        | Regularisasi L1 (0–5)                                 |
# | `reg_lambda`       | Regularisasi L2 (0–5)                                 |
#
# ---
#
# ### **Perbedaan dengan Tuning Random Forest**
#
# | Komponen           | Random Forest                         | XGBoost                                                                              |
# | ------------------ | ------------------------------------- | ------------------------------------------------------------------------------------ |
# | Model              | `RandomForestRegressor`               | `XGBRegressor`                                                                       |
# | Parameter khas     | `bootstrap`, `min_samples_split`, dll | `learning_rate`, `gamma`, `reg_alpha`, `reg_lambda`, `subsample`, `colsample_bytree` |
# | Objective Function | Default (`squared_error`)             | `"reg:absoluteerror"` (absolute loss)                                                |
# | Algoritma          | Bagging (ensemble pohon independen)   | Boosting (ensemble pohon bertahap)                                                   |
#
# > XGBoost memiliki **parameter lebih kompleks dan fleksibel**, sehingga memungkinkan **tuning yang lebih granular** untuk peningkatan performa.

# %%
import optuna
from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score, RepeatedKFold
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error, mean_absolute_error, r2_score, make_scorer
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time

start_time = time.time()

cv = RepeatedKFold(n_splits=5, n_repeats=3, random_state=42)

# Fungsi objective untuk Optuna (minimisasi MAPE)
def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 500),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'gamma': trial.suggest_float('gamma', 0, 5),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 20),
        'reg_alpha': trial.suggest_float('reg_alpha', 0, 5),
        'reg_lambda': trial.suggest_float('reg_lambda', 0, 5),
    }

    model = XGBRegressor(objective="reg:absoluteerror", random_state=42, **params)

    # Gunakan cross-validation untuk menghitung MAPE
    score = cross_val_score(
        model, X_train, y_train, 
        cv=cv, 
        scoring=make_scorer(mean_absolute_percentage_error), 
        n_jobs=-1
    )
    
    mape_mean = score.mean()
    trial.set_user_attr("mape", mape_mean)
    
    return mape_mean

# Jalankan optimisasi
sampler = optuna.samplers.TPESampler(seed=3)
study = optuna.create_study(direction="minimize", sampler=sampler)
study.optimize(objective, n_trials=50, show_progress_bar=True)

# Ambil model terbaik dan latih
best_params = study.best_params
best_xgb = XGBRegressor(objective="reg:absoluteerror", random_state=42, **best_params)
best_xgb.fit(X_train, y_train)
y_pred = best_xgb.predict(X_test)

# Evaluasi performa
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)

# Tambahkan ke results_df
results_df.loc['Tuned XGBoost Regressor (Optuna)'] = [rmse, mae, mape, r2]

# Cetak hasil
print("Best parameters found by Optuna:", best_params)
print("Best cross-validation MAPE from Optuna:", study.best_value)

end_time = time.time()
duration = end_time - start_time
print(f"Hyperparameter tuning selesai dalam {duration:.2f} detik ({duration/60:.2f} menit)")

# Plot konvergensi MAPE per trial
mapes = [t.user_attrs["mape"] for t in study.trials if "mape" in t.user_attrs]
plt.plot(mapes, marker='o')
plt.xlabel("Trial")
plt.ylabel("MAPE")
plt.title("MAPE per Trial")
plt.grid(True)
plt.show()

# Urutkan hasil akhir
results_df = results_df.sort_values(by='MAPE', ascending=True)
results_df
# Out:
# [I 2025-05-23 17:25:21,783] A new study created in memory with name: no-name-61d3f24b-8c7e-4892-86f8-f9138391b480
# Best trial: 0. Best value: 0.154723:   2%|▏         | 1/50 [00:03<02:41,  3.29s/it]
# [I 2025-05-23 17:25:25,080] Trial 0 finished with value: 0.1547234872976939 and parameters: {'n_estimators': 320, 'max_depth': 10, 'learning_rate': 0.026896859411709814, 'subsample': 0.8043310420790653, 'colsample_bytree': 0.9571787817390619, 'gamma': 4.48146544466719, 'min_child_weight': 3, 'reg_alpha': 1.0362143906909338, 'reg_lambda': 0.2573360165041494}. Best is trial 0 with value: 0.1547234872976939.
# Best trial: 0. Best value: 0.154723:   4%|▍         | 2/50 [00:04<01:40,  2.09s/it]
# ...

# %% [markdown]
# ## Perbandingan Hasil Tuning: XGBoost vs Random Forest
#
# Setelah melakukan proses **hyperparameter tuning menggunakan Optuna** untuk dua model terbaik, yaitu **Random Forest** dan **XGBoost**, diperoleh hasil evaluasi akhir seperti berikut:
#
# | Model                                  | MAPE       | MAE     | RMSE     | R²     |
# | -------------------------------------- | ---------- | ------- | -------- | ------ |
# | **Tuned XGBoost Regressor (Optuna)**   | **0.1195** | 9064.02 | 17299.72 | 0.9327 |
# | Tuned Random Forest Regressor (Optuna) | 0.1244     | 8922.45 | 15589.64 | 0.9453 |
#
# ---
#
# ###  Interpretasi Hasil
#
# * Model **Tuned XGBoost Regressor** berhasil mencapai **nilai MAPE terkecil** yaitu **0.1195 atau 11.95%**, yang berarti rata-rata kesalahan prediksi harga mobil hanya sekitar **11.95% dari nilai aslinya**.
# * Nilai ini **lebih rendah** dibandingkan dengan model **Tuned Random Forest** yang memiliki MAPE sebesar **12.44%**.
# * Ini menunjukkan bahwa **tuning pada model XGBoost berhasil meningkatkan akurasi prediksi**, bahkan lebih baik daripada Random Forest, yang sebelumnya merupakan model terbaik tanpa tuning.
#
# ---
#
# ###  Note
#
# * **Tuned Random Forest** memiliki nilai **RMSE dan MAE** yang sedikit lebih kecil, namun tujuan utama tuning kali ini adalah **meminimalkan MAPE** — metrik utama yang mencerminkan kesalahan dalam bentuk **persentase**.
# * Oleh karena itu, **XGBoost yang telah dituning dapat dianggap sebagai model terbaik secara keseluruhan berdasarkan MAPE**.
#
# ---
#
# ###  Hasil Akhir
#
# Model **XGBoost Regressor yang telah dituning** menggunakan Optuna **menghasilkan performa terbaik**, dan akan dipilih sebagai **model final** untuk prediksi harga mobil bekas dalam proyek ini.

# %% [markdown]
# # Feature Importance pada XGBoost: Gain, Weight, dan Cover
#
# XGBoost menyediakan tiga jenis metrik untuk mengukur pentingnya fitur (feature importance) dalam model:
#
# 1. **Gain**
#    - Definisi: Gain adalah rata-rata peningkatan *loss reduction* (pengurangan kerugian) yang diperoleh setiap kali fitur tersebut digunakan untuk melakukan split pada pohon.
#    - Artinya: Fitur dengan gain tinggi berarti fitur tersebut memberikan kontribusi terbesar dalam memperbaiki akurasi model ketika digunakan untuk membagi node.
#    - Intinya: Mengukur seberapa besar fitur meningkatkan performa model saat dipakai split.
#
# 2. **Weight**
#    - Definisi: Weight adalah jumlah berapa kali fitur tersebut digunakan untuk membagi node dalam semua pohon model.
#    - Artinya: Fitur dengan weight tinggi sering dipakai untuk split, tapi belum tentu memberikan peningkatan performa signifikan.
#    - Intinya: Mengukur frekuensi penggunaan fitur sebagai split point tanpa melihat seberapa besar dampaknya.
#
# 3. **Cover**
#    - Definisi: Cover adalah rata-rata jumlah sampel (data points) yang melewati fitur tersebut ketika dipakai untuk split.
#    - Artinya: Fitur dengan cover tinggi mempengaruhi node yang berisi banyak data, sehingga bisa berdampak signifikan pada model.
#    - Intinya: Mengukur cakupan data yang terpengaruh saat fitur tersebut digunakan untuk split.
#
# ---
#
#
#
# | Importance Type | Mengukur                              | Fokus Utama                  |
# |-----------------|-------------------------------------|-----------------------------|
# | Gain            | Rata-rata peningkatan performa split| Seberapa efektif fitur split |
# | Weight          | Jumlah penggunaan fitur sebagai split| Seberapa sering fitur digunakan |
# | Cover           | Rata-rata banyaknya data yang terpengaruh| Cakupan data yang dipengaruhi |

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Ambil importance
gain = best_xgb.get_booster().get_score(importance_type='gain')
weight = best_xgb.get_booster().get_score(importance_type='weight')
cover = best_xgb.get_booster().get_score(importance_type='cover')

# Konversi ke DataFrame & urutkan
df_gain = pd.DataFrame(gain.items(), columns=['Feature', 'Gain']).sort_values(by='Gain', ascending=False).head(10)
df_weight = pd.DataFrame(weight.items(), columns=['Feature', 'Weight']).sort_values(by='Weight', ascending=False).head(10)
df_cover = pd.DataFrame(cover.items(), columns=['Feature', 'Cover']).sort_values(by='Cover', ascending=False).head(10)

# Setup plot 3 baris vertikal
fig, axes = plt.subplots(3, 1, figsize=(10, 12), sharex=False)

# Plot Gain
axes[0].barh(df_gain['Feature'], df_gain['Gain'], color='skyblue')
axes[0].invert_yaxis()
axes[0].set_title('Gain Importance', fontsize=12)
for bar in axes[0].containers[0]:
    width = bar.get_width()
    axes[0].text(width + 0.1, bar.get_y() + bar.get_height()/2,
                 f'{width:.2f}', va='center', fontsize=10)

# Plot Weight
axes[1].barh(df_weight['Feature'], df_weight['Weight'], color='salmon')
axes[1].invert_yaxis()
axes[1].set_title('Weight Importance', fontsize=12)
for bar in axes[1].containers[0]:
    width = bar.get_width()
    axes[1].text(width + max(df_weight['Weight']) * 0.01,
                 bar.get_y() + bar.get_height()/2,
                 f'{width:.0f}', va='center', fontsize=10)

# Plot Cover
axes[2].barh(df_cover['Feature'], df_cover['Cover'], color='lightgreen')
axes[2].invert_yaxis()
axes[2].set_title('Cover Importance', fontsize=12)
for bar in axes[2].containers[0]:
    width = bar.get_width()
    axes[2].text(width + max(df_cover['Cover']) * 0.01,
                 bar.get_y() + bar.get_height()/2,
                 f'{width:.0f}', va='center', fontsize=10)

plt.tight_layout()
plt.show()

# %% [markdown]
# ###  Feature Importance dari Tuned XGBoost Regressor
#
# Setelah mendapatkan model **XGBoost** terbaik melalui proses tuning dengan Optuna, langkah selanjutnya adalah **mengevaluasi fitur mana saja yang paling berkontribusi terhadap prediksi harga mobil bekas**.Dalam XGBoost, terdapat tiga jenis **feature importance** yang umum digunakan:
#
# ---
#
# ### **Gain Importance**
#
# * **Interpretasi**:
#   * Fitur **`Type`** memiliki gain tertinggi (**7.99**), artinya fitur ini memberikan kontribusi terbesar dalam menurunkan loss pada saat training.
#   * Diikuti oleh **`Year`** dan **`Fuel_Type`**, yang juga cukup penting dalam proses split yang meningkatkan akurasi.
#
# ---
#
# ### **Weight Importance**
# * **Interpretasi**:
#   * Fitur **`Mileage`** paling sering digunakan dalam pohon keputusan (7868 kali), disusul oleh `Type` dan `Year`.
#   * Ini mengindikasikan bahwa **Mileage** sering dianggap relevan untuk membuat keputusan, meskipun **tidak selalu menghasilkan gain yang besar**.
#
# ---
#
# ###  **Cover Importance**
# * **Interpretasi**:
#   * Fitur **`Fuel_Type`** memiliki nilai cover tertinggi (**1250**), menunjukkan bahwa setiap kali fitur ini digunakan, ia mempengaruhi sejumlah besar data.
#   * Diikuti oleh **`Gear_Type`** dan **`Type`**, yang juga menjangkau cukup banyak data saat digunakan untuk split.
#
# ---
#
# | Importance Type | Fokus Evaluasi                | Fitur Utama                      |
# | --------------- | ----------------------------- | -------------------------------- |
# | Gain            | Kualitas split (efektivitas)  | `Type`, `Year`, `Fuel_Type`      |
# | Weight          | Frekuensi penggunaan fitur    | `Mileage`, `Type`, `Year`        |
# | Cover           | Cakupan data yang terpengaruh | `Fuel_Type`, `Gear_Type`, `Type` |
#
# Dengan menggabungkan ketiga metrik ini, kita bisa memahami fitur **yang paling penting**, **yang paling sering digunakan**, dan **yang paling luas dampaknya**. Hasil ini bisa digunakan untuk **feature selection**, **interpretasi model**, atau bahkan **menyederhanakan model** di tahap selanjutnya.

# %% [markdown]
# ### Optimization History Plot dari Optuna
#
# Setelah menjalankan proses hyperparameter tuning terhadap model **XGBoost Regressor** menggunakan **Optuna** selama **50 trials**, visualisasi riwayat optimisasi ditampilkan dengan menggunakan:

# %%
from optuna.visualization import plot_optimization_history
plot_optimization_history(study)

# %% [markdown]
# ###  Penjelasan Grafik
# * **Sumbu X** menunjukkan **nomor trial** dari 0 hingga 49.
# * **Sumbu Y** menunjukkan nilai **Objective Value**, dalam hal ini adalah **MAPE (Mean Absolute Percentage Error)** rata-rata dari cross-validation.
# * **Titik biru** (Objective Value) menunjukkan **nilai MAPE** yang dicapai pada masing-masing trial.
# * **Garis merah** (Best Value) menunjukkan **nilai MAPE terbaik sejauh ini**, yang terus diperbarui saat ditemukan nilai yang lebih rendah.
#
# ---
#
# ###  Insight dari Grafik
#
# 1. **Penurunan MAPE Terjadi di Awal**:
#
#    * Dalam 15 trial pertama, terjadi penurunan MAPE yang cukup signifikan, dari sekitar **0.155** ke **sekitar 0.145**.
#    * Ini menunjukkan bahwa Optuna dengan cepat menemukan kombinasi parameter yang lebih baik.
#
# 2. **Stagnasi Menuju Akhir**:
#
#    * Setelah trial ke-30, grafik cenderung stabil. Garis Best Value tetap datar.
#    * Artinya, sebagian besar parameter baru **tidak lagi menghasilkan perbaikan signifikan** terhadap performa model.
#
# 3. **Distribusi yang Konsisten**:
#
#    * Banyak trial setelah titik stabil menghasilkan objective value yang cukup dekat dengan nilai terbaik.
#    * Ini menandakan bahwa ruang parameter telah **dieksplorasi dengan baik**, dan tuning sudah mencapai **konvergensi**.
#
# ---
#
# * Proses tuning dengan **50 trials** sudah cukup untuk menemukan kombinasi parameter terbaik bagi model ini.
# * Nilai MAPE terbaik yang ditemukan dari cross-validation adalah sekitar **0.145**, yang menunjukkan peningkatan akurasi prediksi terhadap harga mobil bekas.

# %% [markdown]
# ### Visualisasi Hyperparameter Importances – Optuna
#
# Setelah melakukan proses tuning terhadap model **XGBoost Regressor**, kita dapat mengetahui **parameter mana yang paling berpengaruh** terhadap hasil tuning (dalam hal ini nilai MAPE) dengan menggunakan plot berikut:

# %%
from optuna.visualization import plot_param_importances
plot_param_importances(study)

# %% [markdown]
# ###  Penjelasan Plot
#
# * Grafik di atas menunjukkan **tingkat kepentingan (importance)** dari masing-masing hyperparameter yang dituning terhadap **penurunan nilai objective** (yaitu **MAPE**).
# * Sumbu X menunjukkan tingkat kontribusi masing-masing parameter.
# * Semakin besar nilai importance, semakin besar pengaruhnya terhadap performa model.
#
# ---
#
# ###  Interpretasi dan Insight
#
# | Hyperparameter         | Importance | Penjelasan                                                                                      |
# | ---------------------- | ---------- | ----------------------------------------------------------------------------------------------- |
# | **max\_depth**         | 0.23       | Mengontrol kedalaman pohon. Terbukti sangat penting dalam menangkap kompleksitas data.          |
# | **gamma**              | 0.21       | Minimum reduction loss untuk split. Sangat berpengaruh dalam mengontrol overfitting.            |
# | **colsample\_bytree**  | 0.16       | Rasio fitur yang digunakan. Menentukan subset fitur yang dipakai oleh tiap pohon.               |
# | **n\_estimators**      | 0.14       | Jumlah pohon. Semakin banyak pohon bisa meningkatkan akurasi, namun rawan overfitting.          |
# | **subsample**          | 0.07       | Rasio sampel data. Memberi variasi pada training untuk mengurangi overfitting.                  |
# | **learning\_rate**     | 0.07       | Menentukan seberapa besar update tiap boosting. Sensitif terhadap overfitting dan underfitting. |
# | **reg\_alpha**         | 0.06       | Regularisasi L1. Membantu generalisasi model.                                                   |
# | **reg\_lambda**        | 0.04       | Regularisasi L2. Berfungsi untuk penalti model kompleks.                                        |
# | **min\_child\_weight** | 0.02       | Minimum total weight per daun. Mempengaruhi pemisahan daun dengan data yang sedikit.            |
#
# ---
#
# * Parameter yang paling memengaruhi kinerja model dalam proses tuning adalah:
#
#   * **`max_depth`** dan **`gamma`**, yang sangat penting dalam mengontrol **kompleksitas pohon dan overfitting**.
#   * Disusul oleh **`colsample_bytree`** dan **`n_estimators`**, yang memengaruhi **keragaman pohon dan kapasitas model**.
# * Parameter seperti **`min_child_weight`** dan **regularisasi** memiliki kontribusi yang lebih kecil dalam studi ini, namun tetap penting sebagai pengontrol overfitting tambahan.

# %% [markdown]
# ###  Menyimpan Model, Encoder, dan Scaler untuk Streamlit Deployment
#
# Setelah proses training dan tuning selesai, langkah selanjutnya adalah **menyimpan model beserta seluruh preprocessing pipeline** (encoder dan scaler) agar dapat digunakan kembali saat aplikasi dijalankan, terutama untuk keperluan **Streamlit**.
#
# ###  Mengapa Perlu Disimpan?
#
# * **Model** yang telah ditraining akan digunakan untuk memprediksi harga mobil bekas pada data baru.
# * **Encoder dan Scaler** diperlukan untuk memastikan bahwa **data baru yang masuk ke Streamlit di-preprocess dengan cara yang sama seperti saat training**. Hal ini penting untuk:
#
#   * Menghindari mismatch fitur
#   * Menjamin konsistensi performa model
# ---
# Dengan menyimpan keempat file tersebut (`.pkl`), maka kita dapat:
# * **Load kembali model dan pipeline** secara langsung saat aplikasi Streamlit berjalan.
# * **Mempersingkat waktu deployment**, karena tidak perlu melakukan retraining atau refitting setiap kali aplikasi dijalankan.
# * **Menjamin akurasi prediksi**, karena seluruh preprocessing dilakukan secara identik dengan training.

# %%
import pickle

# --- Simpan model ke file pickle ---
with open('best_xgb_model.pkl', 'wb') as file:
    pickle.dump(best_xgb, file)
print("Model berhasil disimpan ke 'best_xgb_model.pkl'.")

# --- Simpan target encoder ---
with open('target_encoder.pkl', 'wb') as file:
    pickle.dump(target_encoder, file)
print("Target encoder berhasil disimpan ke 'target_encoder.pkl'.")

# --- Simpan ordinal encoder ---
with open('ordinal_encoder.pkl', 'wb') as file:
    pickle.dump(ordinal_encoder, file)
print("Ordinal encoder berhasil disimpan ke 'ordinal_encoder.pkl'.")

# --- Simpan scaler ---
with open('scaler.pkl', 'wb') as file:
    pickle.dump(scaler, file)
print("Scaler berhasil disimpan ke 'scaler.pkl'.")
# Out:
# Model berhasil disimpan ke 'best_xgb_model.pkl'.
# Target encoder berhasil disimpan ke 'target_encoder.pkl'.
# Ordinal encoder berhasil disimpan ke 'ordinal_encoder.pkl'.
# Scaler berhasil disimpan ke 'scaler.pkl'.

# %% [markdown]
# ## 7. Kesimpulan
#
# ###  **Tujuan Proyek**
#
# Tujuan utama proyek ini adalah untuk membangun model prediktif harga mobil bekas yang akurat, sehingga dapat digunakan oleh dealer, konsumen, dan platform jual-beli mobil untuk menentukan harga jual yang rasional dan kompetitif di pasar Arab Saudi.
#
# ---
#
# ###  **Data Cleaning dan Preprocessing**
# 1. **Dataset** berisi 8.000+ record mobil bekas dari syarah.com.
# 2. **Nilai Tidak Valid**:
#    * Baris dengan `Price = 0` dihapus karena tidak logis secara bisnis.
#    * Kolom `Negotiable` dihapus karena hanya berisi satu nilai (tidak informatif).
# 3. **Outlier Handling**:
#    * Outliers ekstrem dihapus berdasarkan domain knowledge: harga di bawah SAR 5.000 dan di atas SAR 440.000 disaring.
#    * Outlier juga dideteksi dengan **IQR method** untuk fitur numerik `Year`, `Mileage`, `Engine_Size`, dan `Price`.
# 4. **High Cardinality Filtering**:
#    * Tipe mobil (`Type`) yang muncul < 50 kali dihapus untuk mengurangi sparsity dan meningkatkan kestabilan model.
# 5. **Encoding**:
#    * `Type`, `Color`, `Make`: Target Encoding
#    * `Options`, `Gear_Type`, `Fuel_Type`, `Origin`: Ordinal Encoding
# 6. **Feature Scaling**:
#    * Fitur numerik (`Mileage`, `Year`, `Engine_Size`) diskalakan dengan `StandardScaler`.
# ---
#
# ###  **Exploratory Data Analysis (EDA)**
# * **Distribusi Harga** sangat right-skewed, menunjukkan banyak mobil murah dan sedikit mobil premium.
# * **Hubungan Fitur Numerik**:
#   * `Year` dan `Engine_Size` berkorelasi positif dengan `Price`
#   * `Mileage` berkorelasi negatif dengan `Price`
# * **ANOVA Test** menunjukkan fitur-fitur seperti `Type`, `Gear_Type`, `Fuel_Type`, dan `Origin` secara statistik signifikan memengaruhi harga.
# * **Distribusi Kategorikal** mengungkap dominasi Toyota, dan variasi harga yang luas pada warna-warna langka dan model mobil mewah.
# ---
#
# ###  **Modeling dan Evaluasi**
# 1. **Model Regresi yang Dicoba**: Linear Regression, Ridge, Lasso, Elastic Net, KNN, Decision Tree, Random Forest, Gradient Boosting, SVR, XGBoost.
# 2. **Evaluation Metrics**: RMSE, MAE, MAPE, R².
# 3. **Model Terbaik Sebelum Tuning**:
#    * Random Forest dan XGBoost memiliki nilai **MAPE terbaik di kisaran 12.7%**.
# ---
#
# ###  **Hyperparameter Tuning dengan Optuna**
# 1. **Random Forest**:
#    * MAPE turun dari **12.75% → 12.44%**
# 2. **XGBoost**:
#    * Tuning lebih kompleks dengan 9 parameter.
#    * MAPE turun hingga **11.95%**, menjadikannya **model terbaik proyek ini**.
# 3. **Visualisasi Optuna**:
#    * Plot konvergensi menunjukkan stabilisasi nilai MAPE.
#    * Plot parameter importance mengungkap bahwa `max_depth`, `gamma`, dan `colsample_bytree` adalah parameter paling berpengaruh.
# ---
#
# ###  **Deployment**
# Model dan pipeline preprocessing disimpan dalam file `.pkl`:
# * `best_xgb_model.pkl`
# * `target_encoder.pkl`
# * `ordinal_encoder.pkl`
# * `scaler.pkl`
# Ini memudahkan deployment di **Streamlit**, sehingga aplikasi dapat langsung menerima input dan memprediksi harga dengan pipeline yang konsisten seperti saat training.
# ---
#
# ###  **Hasil Akhir**
# Model **Tuned XGBoost Regressor** dengan MAPE **11.95%** berhasil menjadi model prediksi terbaik untuk harga mobil bekas di Arab Saudi.Proyek ini menunjukkan bahwa:
# * Preprocessing yang matang dan tuning hyperparameter secara sistematis mampu menghasilkan prediksi yang andal.
# * Model ini sangat layak digunakan dalam aplikasi nyata berbasis web seperti Streamlit untuk mendukung pengguna akhir dalam mengambil keputusan jual-beli kendaraan.

# %% [markdown]
# ## 8. **Rekomendasi atau Saran**
#
# ###  **Solusi yang Measurable**
#
# Proyek ini berhasil merancang solusi prediktif untuk menentukan harga mobil bekas secara **terukur dan berbasis data** menggunakan model machine learning, khususnya **XGBoost Regressor yang telah dituning dengan Optuna**.
# Solusi yang ditawarkan terbukti **efektif**, ditunjukkan melalui evaluasi menggunakan metrik **MAPE = 11.95%**, yang berarti rata-rata kesalahan prediksi hanya 11.95% dari harga aktual mobil.
# Dengan demikian, solusi ini dapat dinilai sebagai **measurable**, karena:
# * Target utama (penurunan MAPE) tercapai dan terukur.
# * Model dapat digunakan dalam sistem nyata dan dinilai performanya secara kuantitatif terhadap data baru.
# ---
# ###   **Dampak Implementasi Terhadap Proses Bisnis**
# Implementasi solusi prediksi harga mobil bekas ini dapat memberikan dampak nyata dalam proses bisnis:
# * **Platform e-commerce atau marketplace mobil** dapat menampilkan estimasi harga otomatis bagi penjual, meningkatkan transparansi dan kepercayaan pembeli.
# * **Dealer mobil bekas** dapat mengoptimalkan margin keuntungan berdasarkan estimasi harga pasar yang lebih akurat.
# * **Konsumen** dapat membandingkan harga mobil secara objektif sebelum membuat keputusan pembelian.
# * **Lembaga keuangan** seperti leasing dan asuransi dapat mengintegrasikan prediksi harga ini dalam perhitungan pinjaman dan premi.
# Dengan kata lain, solusi ini membantu proses pengambilan keputusan menjadi lebih **cepat, akurat, dan berbasis data**.
# ---
#
# ###  **Batasan Proyek dan Rekomendasi Pengembangan ke Depan**
#
# #### Batasan Proyek:
# * **Data**:
#   * Tidak mencakup informasi penting lain seperti **riwayat servis**, **kondisi fisik**, atau **lokasi geografis aktual**.
#   * Beberapa fitur kategorikal memiliki nilai yang sangat banyak (**high cardinality**) sehingga harus disaring.
# * **Model**:
#   * Hanya diuji pada regresi supervised, belum melibatkan model deep learning atau ensembling tingkat lanjut.
# * **Waktu dan Resource**:
#   * Proyek dibatasi oleh waktu pengerjaan yang singkat sehingga belum dilakukan *feature selection* lanjutan atau integrasi real-time.
#
# #### Rekomendasi untuk Pengembangan Selanjutnya:
#
#   - **Perluasan Dataset:** Integrasikan data tambahan seperti kondisi kendaraan, riwayat servis, dan ulasan pasar untuk meningkatkan cakupan dan representativitas.
#   - **Update Berkala:** Lakukan retraining dan validasi model secara periodik untuk memastikan model tetap akurat seiring dengan perubahan tren pasar.
#   - **Integrasi Umpan Balik:** Kembangkan mekanisme feedback loop dari transaksi nyata untuk terus mengkalibrasi dan meningkatkan performa model.
#   - **Eksplorasi Metode Lanjutan:** Pertimbangkan penggunaan metode hybrid atau deep learning untuk menangani kompleksitas dan non-linearitas yang mungkin tidak tertangkap oleh model saat ini.
#   - **Penambahan Fitur Kontekstual:** Tambahkan fitur-fitur yang lebih kontekstual seperti indikator ekonomi, lokasi penjualan, atau tren musiman untuk meningkatkan prediktabilitas.
